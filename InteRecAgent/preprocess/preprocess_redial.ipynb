# %% [markdown]
# ## Training File Process
# - [ ] extract user history data from conversational data

# %%
import os
import re
import json
import pickle
import numpy as np
import pandas as pd
from typing import *
from rapidfuzz import fuzz
from copy import deepcopy

# %%
train_conv_file = os.path.expanduser("~/work/UniCRS/data/redial/train_data_dbpedia_raw.jsonl")
valid_conv_file = os.path.expanduser("~/work/UniCRS/data/redial/valid_data_dbpedia_raw.jsonl")
test_conv_file = os.path.expanduser("~/work/UniCRS/data/redial/test_data_dbpedia_raw.jsonl")
movie_file = os.path.expanduser("~/blob/raw_datasets/ml-latest/chatbot/movies.ftr")
save_path = os.path.expanduser("~/work/data/redial")

# %%
def read_jsonl(fpath: str) -> List[Dict]:
    res = []
    with open(fpath, 'r') as f:
        for line in f:
            data = json.loads(line)
            res.append(data)
    return res


def write_jsonl(obj: List[Dict], fpath: str) -> None:
    try:
        with open(fpath, 'w') as outfile:
            for entry in obj:
                json.dump(entry, outfile)
                outfile.write('\n')
        print("Sucessfully saved into {}.".format(fpath))
    except Exception as e:
        print(f"Error {e} raised. The temp file would be saved in {fpath}.pkl")
        with open(f"{fpath}.pkl", 'wb') as tempfile:
            pickle.dump(obj, tempfile)
    return

# %%
# load files
test_conv_data = read_jsonl(test_conv_file)
conv_data = read_jsonl(train_conv_file) + read_jsonl(valid_conv_file) + test_conv_data
movies_data = pd.read_feather(movie_file)
available_movies = movies_data['title'].unique()

# %%
def extract_numbers(data_list):  
    numbers = []  
    pattern = r'@(\d+)'  
      
    for item in data_list:  
        text = item.get('text', '')  
        matches = re.finditer(pattern, text)  
        for match in matches:  
            num_str = match.group(1)  
            if num_str not in numbers:  
                numbers.append(num_str)  
    return numbers

def separate_movie_and_year(movie_string):  
    pattern = r"^(.+)\s\((\d{4})\)$"  
    match = re.match(pattern, movie_string)  
      
    if match:  
        movie_name = match.group(1)  
        movie_year = int(match.group(2))  
        return movie_name, movie_year  
    else:  
        return movie_string, None

def attach_labels(conv, movie_ids):
    res = []
    for id in movie_ids:
        labels = conv['initiatorQuestions']
        mentions = conv['movieMentions']
        if id not in labels:
            continue

        if id not in mentions:
            continue

        title_date = conv['movieMentions'][id]
        title, date = separate_movie_and_year(title_date)
        info = {"id": id, 'title': title, 'date': date}
        info.update(labels[id])
        res.append(info)
    return res

# %%
# extract items from conversations
train_item = []
for conv in conv_data:
    items = extract_numbers(conv['messages'])
    train_item.append(attach_labels(conv, items))

print(len(train_item))
print(len(conv_data))
print(train_item[0])
print("Avg Len: ", sum([len(_) for _ in train_item]) / len(train_item))

train_pos_item = []
for data in train_item:
    train_pos_item.append([i for i in data if i['liked']==1])

print("Avg Pos Item: ", sum([len(_) for _ in train_pos_item]) / len(train_pos_item))
print("Total positive interactions: ", sum([len(_) for _ in train_pos_item]))
# Out:
# 11348
# 11348
# [{'id': '169487', 'title': 'Borat', 'date': 2006, 'suggested': 1, 'seen': 1, 'liked': 1}, {'id': '177112', 'title': 'Wedding Crashers', 'date': 2005, 'suggested': 0, 'seen': 1, 'liked': 1}, {'id': '178502', 'title': 'Ted ', 'date': 2012, 'suggested': 1, 'seen': 1, 'liked': 1}, {'id': '155645', 'title': 'Ted 2', 'date': 2015, 'suggested': 1, 'seen': 1, 'liked': 1}, {'id': '78340', 'title': 'Deadpool ', 'date': 2016, 'suggested': 1, 'seen': 1, 'liked': 1}, {'id': '135571', 'title': 'The Hangover', 'date': 2009, 'suggested': 0, 'seen': 1, 'liked': 1}]
# Avg Len:  5.219950652097286
# Avg Pos Item:  4.236693690518153
# Total positive interactions:  48078

# %%
# 
def approx_equal(msg: str, target: str, thres: float=80):
    msg = re.sub(r"[^a-zA-Z0-9\s]", "", msg.lower())
    target = re.sub(r"[^a-zA-Z0-9\s]", "", target.lower())
    if fuzz.ratio(msg, target) > thres:
        return True
    else:
        return False
    

def movie_map(movie, movie_df) -> bool:
    # TODO: 
    map_dict = {}
    approx_map = {}
    title = movie['title']
    date = movie['date']
    movie_df = deepcopy(movie_df)
    # movie_df = movie_df.set_index('title')
    movie_title_set = movie_df['title'].unique()
    if title.lower() in movie_title_set:
        res = movie_df[movie_df['title']==title.lower()]
        if len(res) > 1:
            if date is not None:
                res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
                res = res.loc[res['date_diff'].idxmin()]
            else:
                res = res.iloc[0]
        else:
            res = res.iloc[0]
        id = res['id']
        map_dict[(title, date)] = id
    else:
        scores = []
        for m in movie_title_set:
            scores.append(fuzz.ratio(title.lower(), m))
        max_idx = np.argmax(scores)
        max_scores = scores[max_idx]
        if max_scores >= 90:
            map_dict[(title, date)] = movie_df[movie_df['title']==movie_title_set[max_idx]].iloc[0]['id']
            approx_map[(title, date)] = movie_df.loc[movie_df['title']==movie_title_set[max_idx]].iloc[0]['id']
        else:
            map_dict[(title, date)] = -1
            
    return map_dict, approx_map


movies_from_conversation = set()

for data in train_pos_item:
    for i in data:
        if (i['title'], i['date']) not in movies_from_conversation:
            movies_from_conversation.add((i['title'], i['date']))

movies_from_conversation = [{'title': d[0].strip(), 'date': d[1]} for d in movies_from_conversation]

map_dict = {}
approx_map = {}
movie_df = deepcopy(movies_data)
movie_df['title'] = movies_data['title'].apply(lambda x: x.lower())
for movie in movies_from_conversation:
    _res, _approx = movie_map(movie, movie_df)
    map_dict.update(_res)
    approx_map.update(_approx)
# Out:
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))
# /tmp/ipykernel_3596413/4103755426.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res.loc[:, 'date_diff'] = res['release_date'] - pd.to_datetime(str(date))

# %%
sum([v>0 for v in map_dict.values()]) / len(map_dict), len(approx_map) / len(map_dict)
# Out:
# (0.7282400139542997, 0.04099075527646956)

# %%
len(train_pos_item) == len(conv_data)
# Out:
# True

# %%
no_map = 0
ukn_map = 0
all_cnt = 0
train_pos_item_mapped = []
test_pos_item_mapped = []
test_data_idx = []
for n, data in enumerate(train_pos_item):
    new_data = []
    for i in data:
        if (i['title'].strip(), i['date']) not in map_dict:
            no_map += 1
        else:
            if map_dict[(i['title'].strip(), i['date'])] < 0:
                ukn_map += 1
            else:
                new_data.append(map_dict[(i['title'].strip(), i['date'])])
        all_cnt += 1
    if (n < (len(train_pos_item)-len(test_conv_data))):
        if len(new_data) >= 2:
            train_pos_item_mapped.append(new_data)
    else:
        if len(new_data) >= 2:
            test_pos_item_mapped.append(new_data)
            test_data_idx.append(n)

print(f"No: {no_map/all_cnt}; Unknown: {ukn_map/all_cnt}")
print(f"Mapped train data:  #conv- {len(train_pos_item_mapped)}, #interactions- {sum([len(d) for d in train_pos_item_mapped])}")
print(f"Mapped train data:  #conv- {len(test_pos_item_mapped)}, #interactions- {sum([len(d) for d in test_pos_item_mapped])}")
# Out:
# No: 0.0; Unknown: 0.18696701193893256
# Mapped train data:  #conv- 8920, #interactions- 33837
# Mapped train data:  #conv- 1196, #interactions- 4427

# %%
selected_test_conv = [conv for i, conv in enumerate(test_conv_data) if i+len(train_pos_item)-len(test_conv_data) in test_data_idx]

# %%
selected_test_conv[:2]
# Out:
# [{'movieMentions': {'111776': 'Super Troopers (2001)',
#    '91481': 'Beverly Hills Cop (1984)',
#    '151656': 'Police Academy  (1984)',
#    '134643': 'American Pie  (1999)',
#    '192131': 'American Pie ',
#    '124771': '48 Hrs. (1982)',
#    '94688': 'Police Academy 2: Their First Assignment (1985)',
#    '101794': 'Lethal Weapon (1987)'},
#   'respondentQuestions': {'111776': {'suggested': 0, 'seen': 1, 'liked': 1},
#    '91481': {'suggested': 1, 'seen': 2, 'liked': 2},
#    '151656': {'suggested': 1, 'seen': 0, 'liked': 1},
#    '134643': {'suggested': 0, 'seen': 1, 'liked': 1},
#    '192131': {'suggested': 0, 'seen': 1, 'liked': 1},
#    '124771': {'suggested': 1, 'seen': 2, 'liked': 2},
#    '94688': {'suggested': 1, 'seen': 0, 'liked': 1},
#    '101794': {'suggested': 1, 'seen': 0, 'liked': 2}},
#   'messages': [{'timeOffset': 0,
#     'text': 'Hi I am looking for a movie like @111776',
#     'senderWorkerId': 956,
#     'messageId': 204171,
#     'entity': ['<http://dbpedia.org/resource/Hi_Records>'],
#     'entity_name': ['Hi'],
#     'movie': ['<http://dbpedia.org/resource/Super_Troopers>'],
#     'movie_name': ['Super Troopers (2001)'],
#     'word_name': ['troopers', 'super', 'movie', '2001']},
#    {'timeOffset': 48,
#     'text': 'You should watch @151656',
#     'senderWorkerId': 957,
#     'messageId': 204172,
#     'entity': ['<http://dbpedia.org/resource/Israel>',
#      '<http://dbpedia.org/resource/Watch>'],
#     'entity_name': ['You', 'watch'],
#     'movie': ['<http://dbpedia.org/resource/Police_Academy_(film)>'],
#     'movie_name': ['Police Academy (1984)'],
#     'word_name': ['police', 'watch', 'academy']},
#    {'timeOffset': 90,
#     'text': 'Is that a great one? I have never seen it. I have seen @192131',
#     'senderWorkerId': 956,
#     'messageId': 204173,
#     'entity': ['<http://dbpedia.org/resource/Copula_(linguistics)>',
#      '<http://dbpedia.org/resource/Great_Britain>'],
#     'entity_name': ['Is', 'great'],
#     'movie': ['<http://dbpedia.org/resource/American_Pie_(film)>'],
#     'movie_name': ['American Pie'],
#     'word_name': ['pie', 'american']},
#    {'timeOffset': 122,
#     'text': 'I mean @134643',
#     'senderWorkerId': 956,
#     'messageId': 204174,
#     'entity': [],
#     'entity_name': [],
#     'movie': ['<http://dbpedia.org/resource/American_Pie_(film)>'],
#     'movie_name': ['American Pie (1999)'],
#     'word_name': ['pie', 'american']},
#    {'timeOffset': 180,
#     'text': 'Yes @151656 is very funny and so is @94688',
#     'senderWorkerId': 957,
#     'messageId': 204175,
#     'entity': ['<http://dbpedia.org/resource/Yes_(band)>',
#      '<http://dbpedia.org/resource/Humour>'],
#     'entity_name': ['Yes', 'funny'],
#     'movie': ['<http://dbpedia.org/resource/Police_Academy_(film)>',
#      '<http://dbpedia.org/resource/Police_Academy_2:_Their_First_Assignment>'],
#     'movie_name': ['Police Academy (1984)',
#      'Police Academy 2: Their First Assignment (1985)'],
#     'word_name': ['funny', 'academy', 'police', '2', 'assignment']},
#    {'timeOffset': 199,
#     'text': 'It sounds like I need to check them out',
#     'senderWorkerId': 956,
#     'messageId': 204176,
#     'entity': ['<http://dbpedia.org/resource/Wikipedia>',
#      '<http://dbpedia.org/resource/Sound>'],
#     'entity_name': ['It', 'sounds'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['check', 'sounds']},
#    {'timeOffset': 219,
#     'text': 'yes you will enjoy them',
#     'senderWorkerId': 957,
#     'messageId': 204177,
#     'entity': [],
#     'entity_name': [],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['enjoy']},
#    {'timeOffset': 253,
#     'text': 'I appreciate your time. I will need to check those out. Are there any others you would recommend?',
#     'senderWorkerId': 956,
#     'messageId': 204178,
#     'entity': ['<http://dbpedia.org/resource/Time>',
#      '<http://dbpedia.org/resource/ARE>'],
#     'entity_name': ['time', 'Are'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['time', 'check', 'recommend']},
#    {'timeOffset': 297,
#     'text': 'yes @101794',
#     'senderWorkerId': 957,
#     'messageId': 204179,
#     'entity': [],
#     'entity_name': [],
#     'movie': ['<http://dbpedia.org/resource/Lethal_Weapon>'],
#     'movie_name': ['Lethal Weapon (1987)'],
#     'word_name': ['lethal', 'weapon']},
#    {'timeOffset': 311,
#     'text': 'Thank you i will watch that too',
#     'senderWorkerId': 956,
#     'messageId': 204180,
#     'entity': ['<http://dbpedia.org/resource/Watch>'],
#     'entity_name': ['watch'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['watch']},
#    {'timeOffset': 312,
#     'text': 'and also @91481',
#     'senderWorkerId': 957,
#     'messageId': 204181,
#     'entity': [],
#     'entity_name': [],
#     'movie': ['<http://dbpedia.org/resource/Beverly_Hills_Cop>'],
#     'movie_name': ['Beverly Hills Cop (1984)'],
#     'word_name': ['hills', 'beverly', 'cop']},
#    {'timeOffset': 326,
#     'text': 'Thanks for the suggestions.',
#     'senderWorkerId': 956,
#     'messageId': 204182,
#     'entity': ['<http://dbpedia.org/resource/Gratitude>',
#      '<http://dbpedia.org/resource/Spelling_suggestion>'],
#     'entity_name': ['Thanks', 'suggestions'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['suggestions']},
#    {'timeOffset': 341,
#     'text': 'you are welcome',
#     'senderWorkerId': 957,
#     'messageId': 204183,
#     'entity': [],
#     'entity_name': [],
#     'movie': [],
#     'movie_name': [],
#     'word_name': []},
#    {'timeOffset': 408,
#     'text': 'and also @124771',
#     'senderWorkerId': 957,
#     'messageId': 204184,
#     'entity': [],
#     'entity_name': [],
#     'movie': ['<http://dbpedia.org/resource/48_Hrs.>'],
#     'movie_name': ['48 Hrs. (1982)'],
#     'word_name': ['hrs', '48']},
#    {'timeOffset': 518,
#     'text': 'thanks goodbye',
#     'senderWorkerId': 956,
#     'messageId': 204185,
#     'entity': ['<http://dbpedia.org/resource/Parting_phrase>'],
#     'entity_name': ['goodbye'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['goodbye']}],
#   'conversationId': '20001',
#   'respondentWorkerId': 957,
#   'initiatorWorkerId': 956,
#   'initiatorQuestions': {'111776': {'suggested': 0, 'seen': 1, 'liked': 1},
#    '91481': {'suggested': 1, 'seen': 2, 'liked': 2},
#    '151656': {'suggested': 1, 'seen': 0, 'liked': 1},
#    '134643': {'suggested': 0, 'seen': 1, 'liked': 1},
#    '192131': {'suggested': 0, 'seen': 1, 'liked': 1},
#    '124771': {'suggested': 1, 'seen': 2, 'liked': 2},
#    '94688': {'suggested': 1, 'seen': 0, 'liked': 1},
#    '101794': {'suggested': 0, 'seen': 2, 'liked': 2}}},
#  {'movieMentions': {'204334': 'Happy Death Day  (2017)',
#    '125431': 'Annabelle  (2014)',
#    '118338': 'The Forest  (2016)',
#    '205430': 'A Quiet Place (2018)',
#    '132562': 'The Last House on the Left  (1972)',
#    '157765': 'The Heat  (2013)',
#    '111776': 'Super Troopers (2001)',
#    '187061': 'Identity Thief (2013)',
#    '175203': 'Hot Tub Time Machine',
#    '77161': 'A Nightmare on Elm Street (1984)'},
#   'respondentQuestions': {'204334': {'suggested': 1, 'seen': 2, 'liked': 2},
#    '125431': {'suggested': 0, 'seen': 1, 'liked': 1},
#    '118338': {'suggested': 0, 'seen': 1, 'liked': 1},
#    '205430': {'suggested': 1, 'seen': 2, 'liked': 2},
#    '132562': {'suggested': 0, 'seen': 1, 'liked': 1},
#    '187061': {'suggested': 1, 'seen': 2, 'liked': 2},
#    '111776': {'suggested': 1, 'seen': 2, 'liked': 2},
#    '157765': {'suggested': 1, 'seen': 2, 'liked': 2},
#    '175203': {'suggested': 1, 'seen': 2, 'liked': 2},
#    '77161': {'suggested': 0, 'seen': 1, 'liked': 1}},
#   'messages': [{'timeOffset': 0,
#     'text': 'Hello!',
#     'senderWorkerId': 958,
#     'messageId': 204187,
#     'entity': ['<http://dbpedia.org/resource/Hello>'],
#     'entity_name': ['Hello!'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': []},
#    {'timeOffset': 8,
#     'text': 'Hello!',
#     'senderWorkerId': 959,
#     'messageId': 204188,
#     'entity': ['<http://dbpedia.org/resource/Hello>'],
#     'entity_name': ['Hello!'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': []},
#    {'timeOffset': 30,
#     'text': 'What kind of movies do you like?',
#     'senderWorkerId': 958,
#     'messageId': 204189,
#     'entity': ['<http://dbpedia.org/resource/String_theory>',
#      '<http://dbpedia.org/resource/Kindness>'],
#     'entity_name': ['What', 'kind'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['movies']},
#    {'timeOffset': 60,
#     'text': 'I am looking for a movie recommendation.   When I was younger I really enjoyed the @77161',
#     'senderWorkerId': 959,
#     'messageId': 204190,
#     'entity': ['<http://dbpedia.org/resource/Time>',
#      '<http://dbpedia.org/resource/Youngest_son>'],
#     'entity_name': ['When', 'younger'],
#     'movie': ['<http://dbpedia.org/resource/A_Nightmare_on_Elm_Street>'],
#     'movie_name': ['A Nightmare on Elm Street (1984)'],
#     'word_name': ['recommendation',
#      'movie',
#      'enjoyed',
#      'nightmare',
#      'elm',
#      'street']},
#    {'timeOffset': 82,
#     'text': 'Oh, you like scary movies?',
#     'senderWorkerId': 958,
#     'messageId': 204191,
#     'entity': ['<http://dbpedia.org/resource/Seung-hwan_Oh>',
#      '<http://dbpedia.org/resource/Film>'],
#     'entity_name': ['Oh', 'movies'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['scary', 'movies']},
#    {'timeOffset': 99,
#     'text': 'I recently watched @204334',
#     'senderWorkerId': 958,
#     'messageId': 204192,
#     'entity': [],
#     'entity_name': [],
#     'movie': ['<http://dbpedia.org/resource/Happy_Death_Day>'],
#     'movie_name': ['Happy Death Day (2017)'],
#     'word_name': ['watched', 'day', 'happy', 'death']},
#    {'timeOffset': 101,
#     'text': 'I also enjoyed watching @132562',
#     'senderWorkerId': 959,
#     'messageId': 204193,
#     'entity': ['<http://dbpedia.org/resource/Whale_watching>'],
#     'entity_name': ['watching'],
#     'movie': ['<http://dbpedia.org/resource/The_Last_House_on_the_Left>'],
#     'movie_name': ['The Last House on the Left (1972)'],
#     'word_name': ['watching', 'enjoyed', 'house', 'left']},
#    {'timeOffset': 115,
#     'text': 'It was really good for a new &quot;scary movie&quot;',
#     'senderWorkerId': 958,
#     'messageId': 204194,
#     'entity': ['<http://dbpedia.org/resource/It>',
#      '<http://dbpedia.org/resource/Goods>',
#      '<http://dbpedia.org/resource/Scary_Movie>'],
#     'entity_name': ['It', 'good', 'scary movie'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['scary', 'movie']},
#    {'timeOffset': 141,
#     'text': 'I do enjoy some of the newer horror movies that I have seen as well.',
#     'senderWorkerId': 959,
#     'messageId': 204195,
#     'entity': ['<http://dbpedia.org/resource/Contemporary_R&B>',
#      '<http://dbpedia.org/resource/Horror_film>'],
#     'entity_name': ['newer', 'horror movies'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['enjoy', 'horror', 'movies']},
#    {'timeOffset': 163,
#     'text': 'I heard that @205430 is good. It is still in theaters though.',
#     'senderWorkerId': 958,
#     'messageId': 204196,
#     'entity': ['<http://dbpedia.org/resource/Goods>',
#      '<http://dbpedia.org/resource/It>',
#      '<http://dbpedia.org/resource/Theatre>'],
#     'entity_name': ['good', 'It', 'theaters'],
#     'movie': ['<http://dbpedia.org/resource/A_Quiet_Place>'],
#     'movie_name': ['A Quiet Place (2018)'],
#     'word_name': ['heard', 'theaters', 'quiet']},
#    {'timeOffset': 168,
#     'text': 'I really liked the movie @125431',
#     'senderWorkerId': 959,
#     'messageId': 204197,
#     'entity': [],
#     'entity_name': [],
#     'movie': ['<http://dbpedia.org/resource/Annabelle_(film)>'],
#     'movie_name': ['Annabelle (2014)'],
#     'word_name': ['movie', 'annabelle']},
#    {'timeOffset': 173,
#     'text': 'Me, too!',
#     'senderWorkerId': 958,
#     'messageId': 204198,
#     'entity': ['<http://dbpedia.org/resource/Methyl_group>'],
#     'entity_name': ['Me'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': []},
#    {'timeOffset': 183,
#     'text': 'It was really creepy, but I thought it was good!',
#     'senderWorkerId': 958,
#     'messageId': 204199,
#     'entity': ['<http://dbpedia.org/resource/Wikipedia>',
#      '<http://dbpedia.org/resource/Creepiness>',
#      '<http://dbpedia.org/resource/Goods>'],
#     'entity_name': ['It', 'creepy', 'good'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['creepy']},
#    {'timeOffset': 245,
#     'text': 'Or @118338 I saw while in theaters, this was a very good movie.  It had me on the edge of my seat for the whole show.',
#     'senderWorkerId': 959,
#     'messageId': 204200,
#     'entity': ['<http://dbpedia.org/resource/Or_(heraldry)>',
#      '<http://dbpedia.org/resource/Movie_theater>',
#      '<http://dbpedia.org/resource/Good_Movie>',
#      '<http://dbpedia.org/resource/Wikipedia>',
#      '<http://dbpedia.org/resource/Glossary_of_graph_theory>',
#      '<http://dbpedia.org/resource/County_seat>'],
#     'entity_name': ['Or', 'theaters', 'good movie', 'It', 'edge', 'seat'],
#     'movie': ['<http://dbpedia.org/resource/The_Forest_(2016_film)>'],
#     'movie_name': ['The Forest (2016)'],
#     'word_name': ['movie', 'forest', 'theaters', 'edge', 'seat']},
#    {'timeOffset': 274,
#     'text': "I'm not sure if I saw that one, I'll have to check into it. Sounds familiar, but not sure. Thank you for your suggestions!",
#     'senderWorkerId': 958,
#     'messageId': 204201,
#     'entity': ['<http://dbpedia.org/resource/Wikipedia>',
#      "<http://dbpedia.org/resource/I'll>",
#      '<http://dbpedia.org/resource/Sound>',
#      '<http://dbpedia.org/resource/Familiar>',
#      '<http://dbpedia.org/resource/Spelling_suggestion>'],
#     'entity_name': ["I'm", "I'll", 'Sounds', 'familiar', 'suggestions'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['familiar', 'check', 'sounds', 'suggestions']},
#    {'timeOffset': 310,
#     'text': 'Are there any comedies that you would suggest?',
#     'senderWorkerId': 959,
#     'messageId': 204202,
#     'entity': ['<http://dbpedia.org/resource/ARE>',
#      '<http://dbpedia.org/resource/Comedy>'],
#     'entity_name': ['Are', 'comedies'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['comedies']},
#    {'timeOffset': 376,
#     'text': 'Sure! I like comedies a lot. I like movies like @175203 and @111776 , but I also like @187061 and @157765 .',
#     'senderWorkerId': 958,
#     'messageId': 204203,
#     'entity': ['<http://dbpedia.org/resource/Rexona>',
#      '<http://dbpedia.org/resource/Comedy>',
#      '<http://dbpedia.org/resource/Land_lot>'],
#     'entity_name': ['Sure', 'comedies', 'lot'],
#     'movie': ['<http://dbpedia.org/resource/The_Heat_(film)>',
#      '<http://dbpedia.org/resource/Super_Troopers>',
#      '<http://dbpedia.org/resource/Identity_Thief>',
#      '<http://dbpedia.org/resource/Hot_Tub_Time_Machine>'],
#     'movie_name': ['The Heat (2013)',
#      'Super Troopers (2001)',
#      'Identity Thief (2013)',
#      'Hot Tub Time Machine'],
#     'word_name': ['lot',
#      'hot',
#      '2001',
#      'movies',
#      'machine',
#      'heat',
#      'identity',
#      'troopers',
#      'tub',
#      'time',
#      'super',
#      'thief',
#      'comedies']},
#    {'timeOffset': 410,
#     'text': 'Wonderful! Thank you so much I think I am ready for movie night now.',
#     'senderWorkerId': 959,
#     'messageId': 204204,
#     'entity': ['<http://dbpedia.org/resource/Maximum_Fun>',
#      '<http://dbpedia.org/resource/Reorganization_plan_of_United_States_Army>',
#      '<http://dbpedia.org/resource/Night>'],
#     'entity_name': ['Wonderful!', 'ready', 'night'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['ready', 'night', 'movie', 'wonderful']},
#    {'timeOffset': 422,
#     'text': 'No problem! Thank you, too! :)',
#     'senderWorkerId': 958,
#     'messageId': 204205,
#     'entity': ['<http://dbpedia.org/resource/No_Problem!_(TV_series)>'],
#     'entity_name': ['No problem!'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': []}],
#   'conversationId': '20041',
#   'respondentWorkerId': 958,
#   'initiatorWorkerId': 959,
#   'initiatorQuestions': {'204334': {'suggested': 1, 'seen': 2, 'liked': 2},
#    '125431': {'suggested': 0, 'seen': 1, 'liked': 1},
#    '118338': {'suggested': 0, 'seen': 1, 'liked': 1},
#    '205430': {'suggested': 1, 'seen': 2, 'liked': 2},
#    '132562': {'suggested': 0, 'seen': 1, 'liked': 1},
#    '187061': {'suggested': 1, 'seen': 2, 'liked': 2},
#    '111776': {'suggested': 1, 'seen': 2, 'liked': 2},
#    '157765': {'suggested': 1, 'seen': 2, 'liked': 2},
#    '175203': {'suggested': 1, 'seen': 2, 'liked': 2},
#    '77161': {'suggested': 0, 'seen': 1, 'liked': 1}}}]

# %%
import re
def get_first_time_appear(messages):
    movies = {}
    movie_pattern = re.compile(r'@\d+')
    for i, text in enumerate(messages):
        match = re.findall(movie_pattern, text['text'])
        if match:
            for m in match:
                if m[1:] not in movies:
                    movies[m[1:]] = i
                else:
                    pass
        else:
            pass
    return movies

def merge_conversation(conv, turn):
    movieid2name = conv['movieMentions']
    def convert(match):
        movieid = match.group(0)[1:]
        if movieid in movieid2name:
            movie_name = movieid2name[movieid]
            return movie_name
        else:
            return match.group(0)
    movie_pattern = re.compile(r'@\d+')
    seeker_id = conv['initiatorWorkerId']
    reco_id = conv['respondentWorkerId']
    messages = conv['messages']
    res = ""
    for m in messages[: turn]:
        if m['senderWorkerId'] == seeker_id:
            role = "User"
        else:
            role = "Assistent"
        text = re.sub(movie_pattern, convert, m['text'])
        res += f"{role}: {text}\n"
    return res

def process_conv(conv):
    seeker_ques = conv['initiatorQuestions']
    first_appear_time = get_first_time_appear(conv['messages'])
    try:
        pos_items = {i for i, q in seeker_ques.items() if q['liked']==1 and q['suggested']==1}
    except:
        return None
    if len(pos_items) == 0:
        return None
    turn = -1
    for item in pos_items:
        if first_appear_time[item] > turn:
            target = item
            turn = first_appear_time[item]
    
    if turn <= 0:
        return None
    context = merge_conversation(conv, turn)

    return {'context': context, 'target': conv['movieMentions'][target]}

# %%
selected_processed_test = []
for conv in selected_test_conv[:50]:
    c = process_conv(conv)
    if c:
        selected_processed_test.append(c)
    else:
        continue

write_jsonl(selected_processed_test, os.path.join(save_path, "../test_data_50.jsonl"))

# %%
selected_processed_test
# Out:
# [{'context': 'User: Hi I am looking for a movie like Super Troopers (2001)\nAssistent: You should watch Police Academy  (1984)\nUser: Is that a great one? I have never seen it. I have seen American Pie \nUser: I mean American Pie  (1999)\n',
#   'target': 'Police Academy 2: Their First Assignment (1985)'},
#  {'context': "Assistent: Tell me what would you like to watch?\nUser: Easy A (2010)\nAssistent: Did you watch Avengers: Infinity War (2018) ?\nAssistent: Or The Black Panthers: Vanguard of the Revolution (2015) ?\nAssistent: i really liked it\nUser: No , I think I would like to watch Easy A (2010)\nUser: It's funny\nAssistent: But You already know what you want to watch\nAssistent: You should tell me what kind of movies you like\nAssistent: Did you watch Click  (2006) ?\nAssistent: Do you like scary movies?\n",
#   'target': 'It  (2017)'},
#  {'context': "User: i would like to watch any movie\nUser: Tell me any movie\nUser: Like Avengers: Infinity War (2018)\nAssistent: Have you seen The Avengers  (2012)\nUser: i really enjoyed that one\nUser: Yes and i liked it\nUser: Which another one would you recommend me?\nAssistent: Do you like scary\nAssistent: Have you seen It  (2017)\nUser: i watched Iron Man 2 (2010)  and a liked it\nAssistent: Or Cabin by the Lake (2000)\nUser: No, i have not seen It  (2017)\nUser: But i'll try\nUser: Thank you for helping me\nUser: Good bye\n",
#   'target': 'Ant-Man  (2015)'},
#  {'context': 'Assistent: What kind of movies do you like\nAssistent: have you seen Avengers: Infinity War (2018) ?\nAssistent: or Spider-Man  (2002)\nUser: Yes and i liked them\nUser: Those are awesome\nUser: I like that kind of movies\nAssistent: X-Men: First Class (2011)\nUser: i also watched Iron Man  (2008)\nAssistent: those are good movies as well\nUser: No, i have not watched that one\nUser: i think i will try that one\n',
#   'target': 'X-Men: The Last Stand (2006)'},
#  {'context': "Assistent: Tell me what kind of movies do you like?\nUser: I like scary movies\nAssistent: did you watch Avengers: Infinity War (2018)\nUser: i did not but i want to\nAssistent: So, did you watch It  (2017) ?\nUser: have you seen It  (2017)\nAssistent: And It (1990) ?\nUser: no but i like the old one\nUser: yes i like that versio\nAssistent: Yes i have, that's why i told you\nUser: yes i like that version\n",
#   'target': 'The Exorcist  (1973)'},
#  {'context': 'User: I like to watch scary movies\nAssistent: tell me what kind of movie do you like?\nAssistent: Did you watch It  (2017) ?\nAssistent: And It (1990) ?\nUser: I have seen the old one\nAssistent: Did you watch The Exorcist  (1973) ?\nUser: i have not seen the new one\nUser: i do like the excorcist\nAssistent: Ok, you should watch the new one\nAssistent: Even though i would rather the old one\n',
#   'target': 'The Last Exorcism (2010)'},
#  {'context': 'Assistent: Tell me what kind of movies do you like?\nUser: I love to watch funny movies\nAssistent: Did you watch Click  (2006) ?\nUser: yes, i love adam sandler\nAssistent: and The Mask (1988) ?\nAssistent: Yes he is very funny\nAssistent: Do you not like scary movies?\nUser: just watched the mask last night! there is a new one Son of the Mask (2005)\nUser: i like some scary movie\n',
#   'target': "You Don't Mess with the Zohan (2008)"},
#  {'context': 'Assistent: Hello\nAssistent: me what kind of movies do you like?\nUser: I like all movies, what are your suggestions?\nAssistent: Did you watch Avengers: Infinity War (2018) ?\nUser: No heard it is very good\nAssistent: I can tell you to watch Click  (2006)\nAssistent: Yes it is really good\nUser: I love Adam Sandler movies\nAssistent: You can watch too if you want to The Exorcist  (1973)\nAssistent: But that is a scary one\nAssistent: i would recommend you Iron Man  (2008)\nUser: Sounds scary but will have to check it out!\nUser: These are great suggestions\n',
#   'target': 'Spider-Man 3 (2007)'},
#  {'context': 'Assistent: What kind of movies do you like?\nUser: Hello\nUser: i open to any movie\nAssistent: have you seen Avengers: Infinity War (2018)\nUser: yes i liked that one\nUser: actually i want to watch it again\nUser: i also watch Iron Man  (2008)\nAssistent: or the Spider-Man: Homecoming (2017)  was a goid one ot\nUser: i watched Spider-Man 3 (2007) the old one\nUser: i have not seen the new one\n',
#   'target': 'It  (2017)'},
#  {'context': 'Assistent: hi\nUser: hello\nUser: i am open to any movie\nUser: Whatever you recommend\nUser: i watched Avengers: Infinity War (2018) and i liked it\nUser: i also liked Click  (2006)\nUser: i like movies made by Adan Sandler\nUser: As Marvel movies too\nAssistent: My fav movie is The Big Lebowski\nUser: Do you mean The Big Lebowski ?\nUser: i have not seen it but i will try\nUser: i watched Iron Man  (2008) and i really liked\n',
#   'target': 'Click  (2010)'},
#  {'context': "User: Hello\nAssistent: hi\nUser: i'm open to any movie\nUser: What would you recommend me?\nUser: i liked Avengers: Infinity War (2018)\nAssistent: The Big Lebowski is my fav\nUser: i also like scary movies\nUser: i watched The Big Lebowski\nAssistent: how about House of 1000 Corpses (2003)\nUser: i also watched It  (2017)\nUser: NO, i have not seen that one\nUser: i guess i would try that one tomorrow\nUser: i also watched It (1990)  the old one\nUser: Which another one would you recommend me?\nAssistent: its by rob Zombie\nUser: A funny one\nUser: Like Click  (2006)  by Adan Sandler\n",
#   'target': 'Blazing Saddles (1974)'},
#  {'context': "User: Hello\nUser: i would like to see any movie yo recommend me\nUser: i am open to any movie\nAssistent: Are you looking for something older or newer?\nUser: i just watched Avengers: Infinity War (2018)  and i liked it\nUser: Whatever\nUser: I also like old movies\nUser: Like The Exorcist  (1973)\nUser: i can not forget that  movie\nUser: i like scary movies too\nUser: like It (1990) the old one\nUser: i have not seen It  (2017) the new one\nUser: i've heard is very good i do not know\nAssistent: How about the\r\nThe sixth Battalion?\n",
#   'target': 'The Sixth Battalion (1998)'},
#  {'context': 'User: I like scary movies, can you make a suggestion?\n',
#   'target': 'The Conjuring (2013)'},
#  {'context': "User: hello\nAssistent: Hi, I'm looking for a good docutmentary\nUser: i'm open to any movie\nAssistent: any suggestions?\nUser: Man, right now i'm the seeker the person who is looking for movies\nUser: so that means you are the person who recommend\nAssistent: my apologies\nUser: you can read that onto the chat\nUser: Don't worry man we are here to help\nUser: So i'm looking for any movies\nUser: i watched Click  (2006) and i liked it\nAssistent: Have you seen Avengers: Infinity War (2018)\nUser: I like movies made by Adan Sandler\nUser: Yes and i liked it!\nUser: i also watched Iron Man  (2008)\nUser: i like those kind of movies\nUser: i watched Spider-Man: Homecoming (2017) and it was awesome\n",
#   'target': 'Billy Madison (1995)'},
#  {'context': 'Assistent: hello\nUser: Hello, I am looking for some movie recommendations.  Do you have any Horror Movies that you could suggest for me?\nAssistent: I do!\n',
#   'target': 'The Conjuring (2013)'},
#  {'context': 'User: Hello, I am looking for some movie suggestions.  What would you suggest?\nAssistent: Are you looking for movies currently in theatres?  I like A Quiet Place (2018).\nUser: I want to have a movie night with friends.  I have not seen A Quiet Place (2018) but I think it looks really good.  I do love scary movies.\nUser: One of the best scary movies I have seen in recent years is The Forest  (2016) , have you seen this one?\n',
#   'target': 'Annabelle 2 (2017)'},
#  {'context': 'Assistent: Hello, what type of movies do you like?\nUser: whatever\nUser: i just watched Avengers: Infinity War (2018)\nUser: i really liked\nAssistent: I have not seen Avengers: Infinity War (2018)\nUser: i also watched It  (2017)\nUser: the new one i have not seen the old one It (1990)\n',
#   'target': 'Annihilation  (2018)'},
#  {'context': 'Assistent: Hello, have you seen the new IT movie?\nUser: I have! I loved it.\nAssistent: How about the Sixth Sense?\nAssistent: I know it is older but it was good?\nUser: I feel like it was so much more intense than  It (1990)\nAssistent: I agree it was more intense then It(1988)\n',
#   'target': 'The Sixth Sense (1999)'},
#  {'context': 'Assistent: Hello, I heard that you are looking for a movie recommendation.  What sort of movies are you into?\nUser: I like comedies and movies that have really cool cinemotography\nUser: I like 2001: A Space Odyssey  (1968)\nUser: Tangerine  (2015)\nUser: And i watched Enter the Void (2009) last night and it was pretty good\n',
#   'target': 'The Waterboy (1998)'},
#  {'context': "User: Hello\nAssistent: hello!\nUser: i'm looking for any movie\nUser: i just watched Avengers: Infinity War (2018)  and i really liked\nUser: i also watched It  (2017)  it was a little scary\nAssistent: i loved that movie actually haha.\nUser: but i think the old one It (1990) was better\nUser: so what would you recommend me?\nAssistent: I wanted it in theaters and wow. I just wanted Happy Death Day  (2017) haha thats as scary as i can go\nUser: i have not seen it i think i will try\n",
#   'target': 'Creed  (2015)'},
#  {'context': "Assistent: Hello can you tell me what kind of movies you like best?\nUser: hello\nUser: i'm the seeker now\nUser: you should recommend me any movie\nUser: I just watched Avengers: Infinity War (2018)  and i liked\nAssistent: I could recommend Donnie Darko (2001) .\nUser: That's great\nAssistent: I also enjoy classic horror movies like A Nightmare on Elm Street (1984)  and A Nightmare on Elm Street 2: Freddy's Revenge (1985)\nUser: i have not seen them\nUser: but i could try them\nUser: those sounds very interesting\nUser: i just watched It  (2017)  the new one\nUser: Are those Scary movies too?\n",
#   'target': 'It (1990)'},
#  {'context': 'Assistent: Tell me what would you like to watch?\nAssistent: i just watched Avengers: Infinity War (2018)\nAssistent: Have you seen it?\nAssistent: or do you like Scary movies?\nAssistent: have you ever seen Click  (2006) ?\nUser: I like a lot of different movies.  Thinking about some comedies something like Billy Madison (1995)\n',
#   'target': "You Don't Mess with the Zohan (2008)"},
#  {'context': 'Assistent: hello\nUser: I am looking for a comedy movie.\nAssistent: Tell what kind of movie would you like to watch?\nAssistent: did you watch Click  (2006) ?\nAssistent: i could recommend you American Pie  (1999)\nUser: yes, I loved it.\nUser: American\nAssistent: i could recommend you too American Pie 2 (2001)\nAssistent: There are many of those movies\nUser: Im not sure if i saw american pie 2.\nAssistent: Have you ever seen Scary Movie (2000) ?\nAssistent: Well, you should try them\nUser: scary movie was good.  The first one atleast\n',
#   'target': "You Don't Mess with the Zohan (2008)"},
#  {'context': "User: Hello\nUser: i'm open to any movie\nAssistent: I like old school horror movies like A Nightmare on Elm Street (1984) have you ever seen this one?\nUser: What would you recommend me?\nUser: i have not seen them!\nUser: i think i should try those movies\nAssistent: The second one A Nightmare on Elm Street 2: Freddy's Revenge (1985) is great too.\nUser: i watched The Exorcist  (1973) and it scared me\nAssistent: I love that movie.\nUser: so are there two movies?\nUser: haha, i would not say the same\nUser: i enjoyed It (1990)  the old one\nUser: i think the old one is better than the new one\nAssistent: There are more than two, A Nightmare on Elm Street 3: Dream Warriors (1987) , A Nightmare on Elm Street 4: The Dream Master (1988) , and A Nightmare on Elm Street 5: The Dream Child (1989) .\nUser: Ooh, i will try them\nUser: thank you for helping me good bye\n",
#   'target': 'It  (2017)'},
#  {'context': "User: hello\nUser: i'm open to any movie\nAssistent: Hi there.  I would like to suggest some comedies you could watch, have you seen The Wedding Singer (1998) ?\nUser: i just watched Avengers: Infinity War (2018) and i liked it\nUser: i have not seen it\nUser: but i watched American Pie 2 (2001)  and it was great\nUser: i also watched American Pie  (1999)\n",
#   'target': 'Little Nicky (2000)'},
#  {'context': "User: Hello\nUser: what kind of movies would you recommend me to watched with my friends?\nAssistent: Hello, there is a movie that I have always enjoyed and I'm not sure what you would call the genre but the movie is Donnie Darko (2001)  have you ever seen this one?\nUser: i think funny movies would be great\nUser: Yes i watched it! it was really great!\nAssistent: Well that one definitely isn't funny.  How about Black Sheep  (1996)  or another classic Uncle Buck\nUser: i watched Hangover (2010) i liked very much!\nAssistent: I like that movie too.\nUser: i have not seen that mive\nUser: movie* sorry\nAssistent: So funny and just ridiculous.\nUser: yes and there is the another one Hangover  (2014)\nUser: i think i will try those movies\n",
#   'target': 'Tommy Boy (1995)'},
#  {'context': 'Assistent: Have you seen the movie The Godfather (1972)\nUser: I have seen it once, a long time ago.  It was really good but it might be a little dated for me now.\nAssistent: Yeah its a bit dated for shure\nAssistent: What kind of movie genres do you like\nUser: I enjoy fantasy type movies, and goofy comedies.  Any suggestions?\nAssistent: For me the best fantsy is The Lord of the Rings \nAssistent: Have you seen it\nUser: For example, Big Fish (2003) and Sisters  (2015).\n',
#   'target': 'Step Brothers  (2008)'},
#  {'context': "User: Hello\nAssistent: Hi! Have you seen a good action movie lately?\nUser: It has been a while since I've seen any action films, though I do like movies like X-Men  (2000).\nUser: I have always loved the idea of having some sort of power like they have.\n",
#   'target': 'John Wick (2014)'},
#  {'context': "Assistent: Hello, I hear you are looking for movie recommendations.  Do you have any sort of genre in mind?\nUser: Yes, I'd recommend psychological thrillers.  Have you seen Nocturnal Animals  (2016)?\nAssistent: No I have never seen that one.  I will have to check it out.  Growing up I always like movies like A Nightmare on Elm Street (1984)  and Friday the 13th  (1980) .\nAssistent: As for newer movies I really enjoyed The Forest  (2016) . It was riveting.\nUser: Those are classics.  I'd like to see A Nightmare on Elm Street (1984) or the remake A Nightmare on Elm Street  (2010).\nAssistent: I have not seen the remake.\nUser: Have you seen Arrival  (2016)?\n",
#   'target': 'Annabelle  (2014)'},
#  {'context': 'Assistent: Hello! How are you?\nUser: Hi! Do you have a good movie for me? I like dramas.\nUser: I am great.\nAssistent: Do you like classic dramas like Casablanca, or would you prefer something more recent?\nUser: I really likeI like Casablanca  (1942) a lot. I love old movies.\nUser: I have seen Casablanca  (1942) .\nUser: I like Citizen Kane (1941) too.\n',
#   'target': 'Key Largo  (1948)'},
#  {'context': "User: Hi! How are you?\nUser: I am looking for a funny movie. Can you . help me?\nUser: I really like There's Something About Mary (1998) .\nUser: I like comedies that have a little romance in them.\nAssistent: Hi I'm great thanks, how are you?\nUser: I am great.\nUser: It's a nice day.\nUser: I also really like The Holiday (2006) .\nUser: I like Shallow Hal (2001) too.\nUser: I hope you can help by just suggesting one movie.\n",
#   'target': 'The Wedding Singer (1998)'},
#  {'context': "User: Hi! How are you?\nUser: It is so great to be paired with you.\nAssistent: Hey good thanks and you?\nUser: I am great.\nAssistent: What kind of movies do you like? I love horrors!\nUser: I really love superhero movies like Guardians of the Galaxy  (2014) and Guardians of the Galaxy Vol. 2 (2017) .\nUser: Can you suggest a couple superhero movies for me to watch tonight?\nAssistent: That's great my brother also likes those movies so I can recommend some for you\nUser: Awesome.\nAssistent: Have you seen Avengers: Age of Ultron (2015)\nUser: No I have not seen Avengers: Age of Ultron (2015) . I know people that really like it. I will have to watch it. I do really like Spider-Man  (2002) . I am sure I will love it.\n",
#   'target': 'Captain America: Civil War (2016)'},
#  {'context': "Assistent: Hey how are you?\nUser: Hi! How are you today?\nAssistent: I'm great thanks, What kind of movies do you like?\nUser: I am hoping you can help me find a movie about gangsters, like Casino  (1995) . I love that movie. I also really like Goodfellas (1990) .\nUser: Anything related to the mob interests me.\nAssistent: They are great movies, have you seen American Gangster  (2007)\nUser: I have not seen it, what is it about?\nUser: Is it like the Godfather  (1991) ?\nAssistent: It's based on 1970's in New York\nUser: Oh, cool. That sounds like something I would like for sure.\n",
#   'target': 'Scarface  (1983)'},
#  {'context': "Assistent: Hey how are you?\nUser: Hi! How are you?\nUser: I am great.\nAssistent: Good thanks, what kind of movies do you like?\nUser: I really loved Black Panther (2018) .\nUser: I love adventure movies.\nAssistent: That's great it's a great movies. Have you seen Tomb Raider (2018)\nUser: I like stuff like Jurassic Park .\nAssistent: I have't seen Jurassic Park\nUser: Oh, you know what, I haven't seen that. What is it about? Is it like Raiders of the Lost Ark (1981) ?\n",
#   'target': 'Avengers: Infinity War (2018)'},
#  {'context': "Assistent: Hey how are you?\nUser: Hey! I am great. How are you?\nAssistent: I'm great thanks, what kind of movies do you like?\nUser: I really love Disney movies.\nUser: I love Aladdin  (1992) and The Lion King (1994) .\nAssistent: Awesome, have you tried the new Beauty and the Beast  (2017)\nUser: I haven't seen all of them though.\nAssistent: Those are great movies\nUser: Oh, the new one?\nAssistent: Yeh it's a great film\nUser: With the girl from Harry Potter and the Philosopher's Stone  (2001) ?\nUser: I have to watch that!\nAssistent: Yeh that's the one she is a great actress\nUser: That is a great idea. I didn't even think of that.\nUser: Thanks a lot!\n",
#   'target': 'Sleeping Beauty  (2011)'},
#  {'context': 'User: Hello I am looking for some suggestions for an upcoming movie night with firends.\nAssistent: What kinds of movies have you liked before with this group of friends?\nUser: When I was younger I loved watching A Nightmare on Elm Street (1984)\nAssistent: Do your friends also like scary movies?\nUser: And more recently I have enjoyed The Forest  (2016).\nUser: I am not sure of all of their preferences\nUser: I was thinking maybe to have a couple different genres.\nAssistent: Would The Boy  (2016) be a good horror choice?\nUser: Oh I have seen that one too.  It was wuite good, surprised by the ending.\nUser: Sorry I mean Quite\nAssistent: I would also say Deadpool  (2016) could be a good film for a group of people. Funny and with action involved. Lots of super hero movies right now\nUser: I love Deadpool  (2016) and I think you are right that will be a great movie to watch with friends.\nUser: What about a comedy?  I always liked Tommy Boy (1995) or The Wedding Singer (1998) .\n',
#   'target': 'Spaceballs (1987)'},
#  {'context': "Assistent: Hello what kind of movies are you looking for?\nUser: Hi, I love musicals and am looking for some new ones!\nUser: Les Misérables  (2012) is a current favorite\nAssistent: I am not sure that I know many musicals.  I have never seen Les Misérables  (2012).\nAssistent: I have seen Annie  (1982)  as a child.\nUser: I also enjoy The Phantom of the Opera  (2004)\nUser: I have seen Annie but it was sort of meh\nAssistent: I haven't seen that one either.  If anything I am a horror fan all the way.\nAssistent: I grew up watching A Nightmare on Elm Street (1984) and Friday the 13th  (1980).\nUser: I havent seen a lot of horror movies because they terrify me\nAssistent: I like that scared to the couch feeling, though sometimes I have to follow up my horror movies with a great comedy.  Something like The Waterboy (1998).\nUser: I love Adam Sandler! My favorite movie of his is Happy Gilmore (1996)\nUser: Do you know of any other good 90's comedies?\nAssistent: I love Happy Gilmore (1996).\n",
#   'target': 'Black Sheep  (1996)'},
#  {'context': 'Assistent: Hi there are you interested in some classic comedies?\nUser: I am actually looking for movies for my 12 yr olds sleepover\nAssistent: There is a movie called Uncle Buck and it is absolutely hilarious.\nAssistent: Well Uncle Buck is family friendly I could do better I am sure.  How abut The Hunger Games  (2012)  and The Hunger Games: Catching Fire (2013)\nUser: I dont think the kids would be interested in a movie that old. Hunger Games they have seen and love\nAssistent: Well how about Wonder Woman  (2017) .\nUser: They really liked Sky High  (2003) when I showed that to them and Wonder Woman  (2017) could be good too\n',
#   'target': 'X-Men: Apocalypse (2016)'},
#  {'context': 'User: Hello I am looking for some movies to watch can you recommend anything to me?\nAssistent: Yes, what types of movies are you interested in?\nUser: I love all kinds of movies Horror like The Forest  (2016), comedies like Uncle Buck and romances like The Notebook (2013).\n',
#   'target': '21 Jump Street  (2012)'},
#  {'context': 'User: Hi! How are you?\nUser: I really like murder mysteries. Can you help me find one?\nAssistent: Great, how are you?\n',
#   'target': 'Kiss Kiss Bang Bang (2005)'},
#  {'context': 'Assistent: Hi! It is nice to meet you. Would you like to know about a good movie? What kinds of movies do you like?\nUser: I love all types of movies but prefer action drama. how about you?\nAssistent: I like drama too. I really like Titanic (2012) . Do you like that?\nAssistent: Spotlight  (2015)  was awesome. I highly recommend it!\n',
#   'target': 'The Shawshank Redemption (1994)'},
#  {'context': "Assistent: Hey, how's it going?\nUser: Hey it's great\nAssistent: What kind of movies do you like?\nUser: I am looking for a scary movie\nUser: I don't normally watch them\nUser: so I am open to lots of suggestions\nAssistent: I really like A Quiet Place (2018)\nUser: Oh I have never seen it\nUser: I like the old school ones, like Halloween\nAssistent: it was very good. and not too scary or gruesome for someone who doesn't normally watch  them\nUser: Halloween  (1978)\nAssistent: great classic\nUser: or the silly ones like Scream  (1996)\nUser: What about Get Out (2017) ? Did you see that? Is it good?\n",
#   'target': 'The Others  (2001)'}]

# %%
train_data_mapped = train_pos_item_mapped[: -1000]
valid_data_mapped = train_pos_item_mapped[1000:]
test_data_mapped = test_pos_item_mapped
n_user_train = len(train_data_mapped)
n_user_valid = len(valid_data_mapped)
n_user_test = len(test_data_mapped)
train_df = pd.DataFrame({'user_id':list(range(1, n_user_train+1)), 'item_id': train_data_mapped})
valid_df = pd.DataFrame({'user_id':list(range(n_user_train+1, n_user_train+1+n_user_valid)), 'item_id': valid_data_mapped})
test_df = pd.DataFrame({'user_id':list(range(n_user_train+1+n_user_valid, n_user_train+1+n_user_valid+n_user_test)), 'item_id': test_data_mapped})

# %%
valid_history = deepcopy(valid_df)
valid_history['item_id'] = valid_history['item_id'].apply(lambda x: x[:-1])
valid_df['item_id'] = valid_df['item_id'].apply(lambda x: x[-1])

# %%
test_history = deepcopy(test_df)
test_history['item_id'] = test_history['item_id'].apply(lambda x: x[:-1])
test_df['item_id'] = test_df['item_id'].apply(lambda x: x[-1])

# %%
user_history = pd.concat([train_df, valid_history, test_history])
user_history = user_history.explode("item_id")
user_history
# Out:
#       user_id item_id
# 0           1     491
# 0           1     849
# 0           1    4674
# 0           1     512
# 1           2   28300
# ...       ...     ...
# 1193    17034    4237
# 1194    17035    1036
# 1194    17035      28
# 1195    17036     160
# 1195    17036     912
#
# [55346 rows x 2 columns]

# %%
new_train_df = pd.concat([train_df, valid_history])
new_train_df = new_train_df.explode('item_id')
new_train_df
# Out:
#       user_id item_id
# 0           1     491
# 0           1     849
# 0           1    4674
# 0           1     512
# 1           2   28300
# ...       ...     ...
# 7918    15839   27621
# 7918    15839    5697
# 7919    15840    4247
# 7919    15840    7155
# 7919    15840   25613
#
# [52115 rows x 2 columns]

# %%
new_train_df.to_csv(os.path.join(save_path, 'train.csv'), index=None)
valid_df.to_csv(os.path.join(save_path, 'valid.csv'), index=None)
test_df.to_csv(os.path.join(save_path, 'test.csv'), index=None)
user_history.to_csv(os.path.join(save_path, 'user_history.csv'), index=None)
# Out:
# Bad pipe message: %s [b'\x86\xbf\x91-/\x8f\\\r8\x82\xa4Y\xf8\xb8\xabjwU\x00\x00|\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0W\xc0']
# Bad pipe message: %s [b"+\xc0/\x00\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\\xc0`\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0#\xc0'\x00g\x00@\xc0\n\xc0\x14\x009\x008\xc0\t\xc0\x13\x003\x002\x00\x9d\xc0\xa1\xc0\x9d\xc0Q\x00\x9c\xc0\xa0\xc0\x9c\xc0P\x00=\x00<\x005\x00/\x00\x9a\x00"]
# Bad pipe message: %s [b'\xae\xb5.\xd3\n\xe1\x03"\x05xU+;,\x1a\x0f\xfd\x8a\x00\x00\xa6\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0/\x00\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\\xc0`\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0s\xc0w\x00\xc4\x00\xc3\xc0#\xc0\'\x00g\x00@\xc0r\xc0v\x00\xbe\x00\xbd\xc0\n\xc0\x14\x009\x008']
# Bad pipe message: %s [b'Vz\xd3\x9e#\x8c\x7f\xacMk\xa4e7\xb3j\xa1i\xab\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00', b'\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x004\x00\x9b\x00F\xc0\x0e\xc0\x04\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00\x10\x00\r\xc0\x17\x00\x1b\xc0\r\xc0\x03\x00\n\x00\x15\x00\x12\x00\x0f\x00\x0c\x00\x1a\x00\t\x00\x14\x00\x11\x00\x19\x00\x08\x00\x06\x00\x17\x00\x03\xc0\x10\xc0\x06\xc0\x15']
# Bad pipe message: %s [b'\x98\x05\x92\x98\xf4\x16\x01L\xa6)\xa9\xdem\x1e', b'e\r\x00\x00>\xc0\x14\xc0\n\x009\x008\x007\x006\xc0\x0f\xc0\x05\x005\xc0\x13\xc0\t\x003\x002\x001\x000\xc0\x0e\xc0\x04\x00/\x00\x9a\x00\x99\x00\x98\x00\x97\x00\x96\x00\x07\xc0\x11\xc0\x07\xc0\x0c\xc0\x02\x00\x05\x00\x04\x00\xff\x02\x01\x00\x00C\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b']
# Bad pipe message: %s [b'#b\xedh\x85\xdc\xd7\xdcA?\x0c\xc2c\x14?\xa1\xba"']
# Bad pipe message: %s [b'\x8b/1HG-2Z\xe4>\x9c\x0c\x06{2*']
# Bad pipe message: %s [b"BiO\xff\x16t\xc4\x89~H\xd8\xe0A\xd9\xa14\x8a;\x00\x00\x86\xc00\xc0,\xc0(\xc0$\xc0\x14\xc0\n\x00\xa5\x00\xa3\x00\xa1\x00\x9f\x00k\x00j\x00i\x00h\x009\x008\x007\x006\xc02\xc0.\xc0*\xc0&\xc0\x0f\xc0\x05\x00\x9d\x00=\x005\xc0/\xc0+\xc0'\xc0#\xc0\x13\xc0\t\x00\xa4\x00\xa2\x00\xa0\x00\x9e\x00g\x00@\x00?\x00>\x003\x002\x001\x00", b'1\xc0-\xc0)\xc0%\xc0\x0e\xc0\x04\x00\x9c\x00<\x00/\x00\x9a\x00\x99\x00\x98\x00\x97\x00\x96\x00\x07\xc0\x11\xc0\x07\xc0\x0c\xc0\x02\x00\x05\x00\x04\x00\xff\x02\x01\x00\x00']
# Bad pipe message: %s [b'\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x1c\x00\x1a\x00\x17\x00\x19\x00\x1c\x00\x1b\x00\x18\x00\x1a\x00\x16\x00\x0e\x00\r\x00\x0b\x00\x0c\x00\t\x00\n\x00#\x00\x00\x00\r\x00 \x00\x1e\x06\x01\x06\x02\x06\x03\x05\x01\x05\x02\x05\x03\x04\x01\x04\x02\x04\x03\x03\x01\x03\x02\x03\x03\x02\x01\x02\x02\x02\x03\x00\x0f\x00\x01\x01']
# Bad pipe message: %s [b"\xd5\xc5K5\xd9\x99\xa9\xec=\xb8\xf4\xfb\xb8M<7\x97\xfa\x00\x00\xf4\xc00\xc0,\xc0(\xc0$\xc0\x14\xc0\n\x00\xa5\x00\xa3\x00\xa1\x00\x9f\x00k\x00j\x00i\x00h\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00\xa7\x00m\x00:\x00\x89\xc02\xc0.\xc0*\xc0&\xc0\x0f\xc0\x05\x00\x9d\x00=\x005\x00\x84\xc0/\xc0+\xc0'\xc0#\xc0\x13\xc0\t\x00\xa4\x00\xa2\x00\xa0\x00\x9e\x00g\x00@\x00?\x00>\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x00\xa6\x00l\x004\x00\x9b\x00F\xc01\xc0-\xc0)\xc0%\xc0\x0e\xc0\x04\x00\x9c\x00<\x00/\x00\x96\x00A\x00"]
# Bad pipe message: %s [b'\x11\xc0\x07\xc0\x16\x00']
# Bad pipe message: %s [b'\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00\x10\x00\r\xc0\x17\x00\x1b']

# %%
new_train_df.reset_index(inplace=True)
valid_df.reset_index(inplace=True)
test_df.reset_index(inplace=True)
user_history.reset_index(inplace=True)

new_train_df.to_feather(os.path.join(save_path, 'train_redial.ftr'))
valid_df.to_feather(os.path.join(save_path, 'valid_redial.ftr'))
test_df.to_feather(os.path.join(save_path, 'test_redial.ftr'))
user_history.to_feather(os.path.join(save_path, 'user_history_redial.ftr'))

# %%
import random
sampled_test_idx = random.choices(range(0, len(test_conv_data)), k=100)

# %%
sampled_test_samples = [test_conv_data[i] for i in sampled_test_idx]

# %%
train_pos_item
# Out:
# [[{'id': '169487',
#    'title': 'Borat',
#    'date': 2006,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '177112',
#    'title': 'Wedding Crashers',
#    'date': 2005,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '178502',
#    'title': 'Ted ',
#    'date': 2012,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '155645',
#    'title': 'Ted 2',
#    'date': 2015,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '78340',
#    'title': 'Deadpool ',
#    'date': 2016,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '135571',
#    'title': 'The Hangover',
#    'date': 2009,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '184418',
#    'title': 'Get Out',
#    'date': 2017,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '201085',
#    'title': 'The Signal ',
#    'date': 2014,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '194237',
#    'title': 'Shutter Island ',
#    'date': 2010,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '178984',
#    'title': 'Wind River ',
#    'date': 2017,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '140537',
#    'title': 'Sense and Sensibility ',
#    'date': 1995,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '77293',
#    'title': 'A Wrinkle in Time ',
#    'date': None,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '180389',
#    'title': 'On Chesil Beach ',
#    'date': None,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1}],
#  [{'id': '103957',
#    'title': 'A Christmas Story',
#    'date': 1983,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '176542',
#    'title': "National Lampoon's Christmas Vacation",
#    'date': 1989,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '124142',
#    'title': 'Elf ',
#    'date': 2003,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '180808',
#    'title': 'The Santa Clause',
#    'date': 1994,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '201351',
#    'title': 'Scrooged',
#    'date': 1988,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '76356',
#    'title': 'The Parent Trap ',
#    'date': 1998,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '159885',
#    'title': 'The Incredibles',
#    'date': 2004,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '98683',
#    'title': 'Matilda ',
#    'date': 1996,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '161983',
#    'title': 'Mrs. Doubtfire',
#    'date': 1993,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '194147',
#    'title': 'Carrie ',
#    'date': 1976,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '204794',
#    'title': 'It',
#    'date': 1990,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '202190',
#    'title': 'The Shining ',
#    'date': 1980,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '180224',
#    'title': 'The Cabin in the Woods',
#    'date': None,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '184418',
#    'title': 'Get Out',
#    'date': 2017,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '205803',
#    'title': 'Big Bear',
#    'date': 2017,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '81135',
#    'title': 'It Comes at Night',
#    'date': 2017,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1}],
#  [{'id': '184022',
#    'title': 'Transporter 3',
#    'date': 2008,
#    'suggested': 0,
#    'seen': 2,
#    'liked': 1},
#   {'id': '195979',
#    'title': 'Baby Driver ',
#    'date': 2017,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '152153',
#    'title': 'Duel ',
#    'date': 1971,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1}],
#  [{'id': '199262',
#    'title': 'Oldboy ',
#    'date': 2003,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '145161',
#    'title': 'New World ',
#    'date': 2013,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '80264',
#    'title': 'Zinda ',
#    'date': 2006,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '129110',
#    'title': 'Lady Vengeance',
#    'date': 2005,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '189020',
#    'title': 'I Saw the Devil',
#    'date': 2010,
#    'suggested': 1,
#    'seen': 2,
#    'liked': 1}],
#  [{'id': '205803',
#    'title': 'Big Bear',
#    'date': 2017,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '114341',
#    'title': 'Baywatch ',
#    'date': 2017,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '111918',
#    'title': 'Step Brothers ',
#    'date': 2008,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '104378',
#    'title': 'High School Musical ',
#    'date': None,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '127328',
#    'title': 'Hairspray ',
#    'date': 2007,
#    'suggested': 1,
#    'seen': 2,
#    'liked': 1}],
#  [{'id': '143259',
#    'title': 'Yes Man ',
#    'date': 2008,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '111776',
#    'title': 'Super Troopers',
#    'date': 2001,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '152497',
#    'title': 'Bruce Almighty',
#    'date': 2003,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '189328',
#    'title': 'Evan Almighty',
#    'date': 2007,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '107314',
#    'title': "Ocean's Eleven",
#    'date': 2001,
#    'suggested': 1,
#    'seen': 2,
#    'liked': 1},
#   {'id': '122552',
#    'title': 'Hangover',
#    'date': 2010,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '93013',
#    'title': "Daddy's Home ",
#    'date': 2015,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '205695',
#    'title': 'Blockers',
#    'date': 2018,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1}],
#  [{'id': '85961',
#    'title': 'In the Heart of the Sea ',
#    'date': 2015,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '122208',
#    'title': 'Into the Wild ',
#    'date': 2007,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '159497',
#    'title': 'Grizzly Man',
#    'date': 2005,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '165182',
#    'title': 'The Way Back',
#    'date': 2010,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '77293',
#    'title': 'A Wrinkle in Time ',
#    'date': None,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '112365',
#    'title': 'Flubber ',
#    'date': 1997,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '115290',
#    'title': 'Hook ',
#    'date': 1991,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '113972',
#    'title': 'Honey, I Shrunk the Kids',
#    'date': 1989,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '187028',
#    'title': 'It ',
#    'date': 2017,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '115463',
#    'title': 'Saw ',
#    'date': 2004,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '175707',
#    'title': 'Saw III',
#    'date': 2006,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '203822',
#    'title': 'Siren ',
#    'date': None,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1}],
#  [{'id': '170376',
#    'title': 'Blade Runner 2049',
#    'date': 2017,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '172049',
#    'title': 'The Chronicles of Riddick',
#    'date': 2004,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '122389',
#    'title': 'Citizenfour',
#    'date': 2014,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '102326',
#    'title': 'Snowden ',
#    'date': 2016,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '95216',
#    'title': 'JFK ',
#    'date': 1991,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '115688',
#    'title': 'Non-Stop ',
#    'date': 2014,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '160589',
#    'title': 'Flightplan',
#    'date': 2005,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '126916',
#    'title': 'Red Eye ',
#    'date': 2005,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '76160',
#    'title': 'Million Dollar Baby',
#    'date': 2004,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '121678',
#    'title': 'Slumdog Millionaire',
#    'date': 2008,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '145232',
#    'title': 'Great Expectations ',
#    'date': 1946,
#    'suggested': 1,
#    'seen': 2,
#    'liked': 1},
#   {'id': '79954',
#    'title': 'A Christmas Carol ',
#    'date': 2009,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '149313',
#    'title': 'Moby Dick ',
#    'date': 2010,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1}],
#  [{'id': '142069',
#    'title': 'Vacation ',
#    'date': 2015,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '98088',
#    'title': 'Horrible Bosses',
#    'date': 2011,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '178096',
#    'title': "There's Something About Mary",
#    'date': 1998,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '135799',
#    'title': 'Raising Arizona',
#    'date': 1987,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '118888',
#    'title': 'Death Becomes Her',
#    'date': 1992,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '189266',
#    'title': 'Disturbia ',
#    'date': 2007,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '91649',
#    'title': "Vampire's Kiss",
#    'date': 1989,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '129679',
#    'title': 'Leaving Las Vegas',
#    'date': 1995,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '81385',
#    'title': 'Fargo ',
#    'date': 1996,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '140536',
#    'title': 'Blood Simple',
#    'date': 1984,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '175096',
#    'title': 'Titanic ',
#    'date': 1997,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '95066',
#    'title': 'Django Unchained',
#    'date': 2012,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '118316',
#    'title': 'The Amityville Haunting',
#    'date': 2011,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '177112',
#    'title': 'Wedding Crashers',
#    'date': 2005,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '141928',
#    'title': 'Talladega Nights: The Ballad of Ricky Bobby',
#    'date': 2006,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '115155',
#    'title': 'The Sandlot',
#    'date': 1993,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '192326',
#    'title': 'Bad News Bears',
#    'date': 2005,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '141482',
#    'title': 'DodgeBall: A True Underdog Story',
#    'date': 2004,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '84798',
#    'title': 'Pretty Woman',
#    'date': 1990,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '152847',
#    'title': 'How to Lose a Guy in 10 Days',
#    'date': 2003,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '115908',
#    'title': '50 First Dates',
#    'date': 2004,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '188302',
#    'title': 'Ever After',
#    'date': 1998,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '118762',
#    'title': '21 Jump Street ',
#    'date': 2012,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '193168',
#    'title': 'Rush Hour ',
#    'date': 1998,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '127115',
#    'title': 'Hot Fuzz',
#    'date': 2007,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '101691',
#    'title': 'Bad Boys ',
#    'date': 1995,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '160661',
#    'title': 'The Possession',
#    'date': 2012,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '180224',
#    'title': 'The Cabin in the Woods',
#    'date': None,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '158950',
#    'title': 'The Last House on the Left ',
#    'date': 2009,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '165248',
#    'title': 'Let the Right One In ',
#    'date': 2008,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1}],
#  [{'id': '204974',
#    'title': 'Black Panther',
#    'date': 2018,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '78418',
#    'title': 'The Avengers ',
#    'date': 2012,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '196058',
#    'title': 'The Amazing Spider-Man ',
#    'date': 2012,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '177160',
#    'title': 'Justice League ',
#    'date': 2017,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '119144',
#    'title': 'Wonder Woman ',
#    'date': 2017,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '197498',
#    'title': 'Field of Dreams',
#    'date': 1989,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '163215',
#    'title': 'Wonder ',
#    'date': 2017,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '190285',
#    'title': 'Good Will Hunting',
#    'date': 1997,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '117608',
#    'title': 'Mona Lisa Smile',
#    'date': 2003,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '197438',
#    'title': 'Promised Land ',
#    'date': 2012,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '153858',
#    'title': 'Dead Poets Society',
#    'date': 1989,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '110011',
#    'title': 'Manchester by the Sea ',
#    'date': 2016,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '101264',
#    'title': 'Inception',
#    'date': 2010,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '121563',
#    'title': 'As Good as It Gets',
#    'date': 1997,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '197589',
#    'title': 'Kingsman: The Golden Circle',
#    'date': None,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '195979',
#    'title': 'Baby Driver ',
#    'date': 2017,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '107047',
#    'title': "The Hitman's Bodyguard",
#    'date': None,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '78340',
#    'title': 'Deadpool ',
#    'date': 2016,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '204870',
#    'title': 'Deadpool 2 ',
#    'date': 2018,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1}],
#  [{'id': '133813',
#    'title': 'Anchorman: The Legend of Ron Burgundy',
#    'date': 2004,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '95660',
#    'title': 'Central Intelligence',
#    'date': 2016,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '183056',
#    'title': 'The Big Lebowski',
#    'date': None,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '118762',
#    'title': '21 Jump Street ',
#    'date': 2012,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '108934',
#    'title': 'Thor ',
#    'date': None,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '99896',
#    'title': 'Spider-Man ',
#    'date': 2002,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '76706',
#    'title': 'The Incredible Hulk ',
#    'date': 2008,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '78418',
#    'title': 'The Avengers ',
#    'date': 2012,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '138141',
#    'title': 'The Wolverine ',
#    'date': 2013,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1}],
#  [{'id': '111540',
#    'title': 'Dunkirk ',
#    'date': 2017,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '204409',
#    'title': 'Murder on the Orient Express',
#    'date': 2017,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '97494',
#    'title': 'Silence ',
#    'date': 2016,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1}],
#  [],
#  [{'id': '194147',
#    'title': 'Carrie ',
#    'date': 1976,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '184418',
#    'title': 'Get Out',
#    'date': 2017,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '187028',
#    'title': 'It ',
#    'date': 2017,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '202190',
#    'title': 'The Shining ',
#    'date': 1980,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '135508',
#    'title': 'The Babadook',
#    'date': 2014,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '76012',
#    'title': 'The Exorcist ',
#    'date': 1973,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '117972',
#    'title': 'Little Miss Sunshine',
#    'date': 2006,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '78340',
#    'title': 'Deadpool ',
#    'date': 2016,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '115908',
#    'title': '50 First Dates',
#    'date': 2004,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '90253',
#    'title': 'The Waterboy',
#    'date': 1998,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '150451',
#    'title': 'Happy Gilmore',
#    'date': 1996,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '192734',
#    'title': 'Eight Crazy Nights',
#    'date': 2002,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '170722',
#    'title': 'Meet the Parents',
#    'date': 2000,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '127676',
#    'title': 'The Birds ',
#    'date': 1963,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '97819',
#    'title': 'Psycho ',
#    'date': None,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '142376',
#    'title': 'The Snowman ',
#    'date': 2017,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1}],
#  [{'id': '146872',
#    'title': 'Eagle Eye',
#    'date': 2008,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '161313',
#    'title': 'Die Hard',
#    'date': 1988,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '170059',
#    'title': 'Die Hard 2',
#    'date': 1990,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '167064',
#    'title': 'The Fugitive ',
#    'date': 1993,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '166583',
#    'title': 'Skyfall',
#    'date': 2012,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1}],
#  [{'id': '161385',
#    'title': 'Caddyshack',
#    'date': 1980,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '120948',
#    'title': 'Groundhog Day ',
#    'date': 1993,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '173333',
#    'title': 'Monty Python and the Holy Grail',
#    'date': 1975,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '200089',
#    'title': 'St. Vincent ',
#    'date': 2014,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '99910',
#    'title': 'Blazing Saddles',
#    'date': 1974,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '111099',
#    'title': 'Catch Me If You Can',
#    'date': 2002,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '188808',
#    'title': "Schindler's List",
#    'date': 1993,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '170305',
#    'title': 'John Wick: Chapter 2',
#    'date': 2017,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '148904',
#    'title': 'John Wick',
#    'date': 2014,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '129362',
#    'title': 'Geostorm',
#    'date': 2017,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1}],
#  [{'id': '170037',
#    'title': 'The Big Sick',
#    'date': 2017,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '118748',
#    'title': 'The Choice ',
#    'date': 2016,
#    'suggested': 0,
#    'seen': 0,
#    'liked': 1},
#   {'id': '115908',
#    'title': '50 First Dates',
#    'date': 2004,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '175096',
#    'title': 'Titanic ',
#    'date': 1997,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '151702',
#    'title': 'Harold & Kumar Escape from Guantanamo Bay',
#    'date': 2008,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '165991',
#    'title': 'Harold & Kumar Go to White Castle',
#    'date': 2004,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '178711',
#    'title': 'Sleepless in Seattle',
#    'date': 1993,
#    'suggested': 0,
#    'seen': 0,
#    'liked': 1},
#   {'id': '201259',
#    'title': "You've Got Mail",
#    'date': 1998,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1}],
#  [{'id': '204331',
#    'title': 'Girls Trip',
#    'date': 2017,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '190814',
#    'title': 'Pitch Perfect',
#    'date': 2012,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '89725',
#    'title': 'Pitch Perfect 2',
#    'date': 2015,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '205060',
#    'title': 'Pitch Perfect 3',
#    'date': 2017,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '79106',
#    'title': 'Raging Bull',
#    'date': 1980,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '191947',
#    'title': 'Southpaw ',
#    'date': 2015,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '199038',
#    'title': 'Heat ',
#    'date': 1996,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '191015',
#    'title': 'Rocky ',
#    'date': 2013,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '143583',
#    'title': 'Real Genius',
#    'date': 1985,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '160919',
#    'title': 'The Fighter',
#    'date': 2010,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '205124',
#    'title': 'Mom and Dad',
#    'date': 2017,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '153194',
#    'title': 'Snake Eyes ',
#    'date': 1998,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '180899',
#    'title': 'National Treasure ',
#    'date': 2004,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '109424',
#    'title': 'National Treasure: Book of Secrets',
#    'date': 2007,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '171914',
#    'title': 'Con Air',
#    'date': 1997,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '139492',
#    'title': 'The Rock ',
#    'date': 1996,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '202190',
#    'title': 'The Shining ',
#    'date': 1980,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '102691',
#    'title': 'Room 237',
#    'date': 2012,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '78977',
#    'title': 'The Haunting ',
#    'date': 1999,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '185171',
#    'title': 'The Conjuring',
#    'date': 2013,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '181299',
#    'title': 'The Shawshank Redemption',
#    'date': 1994,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '78480',
#    'title': 'The Green Mile ',
#    'date': 1999,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '193591',
#    'title': 'Escape from Alcatraz ',
#    'date': 1979,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '165085',
#    'title': 'Escape from L.A.',
#    'date': 1996,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '114271',
#    'title': 'Escape from New York',
#    'date': 1981,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1}],
#  [{'id': '142823',
#    'title': 'The Revenant ',
#    'date': 2015,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '146640',
#    'title': 'Prisoners ',
#    'date': 2013,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '93489',
#    'title': 'Equilibrium ',
#    'date': 2002,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '114932',
#    'title': 'Braveheart',
#    'date': 1995,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '198772',
#    'title': 'Total Recall ',
#    'date': 1990,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '107265',
#    'title': 'Mulan',
#    'date': 2009,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '137860',
#    'title': 'Cinderella ',
#    'date': 1947,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '131551',
#    'title': 'The Adventures of Robin Hood',
#    'date': 1938,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '112365',
#    'title': 'Flubber ',
#    'date': 1997,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '185356',
#    'title': 'The Absent-Minded Professor',
#    'date': 1961,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '124142',
#    'title': 'Elf ',
#    'date': 2003,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '196478',
#    'title': 'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#    'date': 2005,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '114909',
#    'title': 'Crouching Tiger, Hidden Dragon',
#    'date': 2000,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '181941',
#    'title': 'Fist of Fury',
#    'date': 1972,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '152955',
#    'title': 'Enter the Dragon',
#    'date': 1973,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '117347',
#    'title': 'Once Upon a Time in China',
#    'date': 1991,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '193168',
#    'title': 'Rush Hour ',
#    'date': 1998,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '95621',
#    'title': 'Rush Hour 2',
#    'date': 2001,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '101264',
#    'title': 'Inception',
#    'date': 2010,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '172067',
#    'title': 'Shutter ',
#    'date': 2012,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '181299',
#    'title': 'The Shawshank Redemption',
#    'date': 1994,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '194237',
#    'title': 'Shutter Island ',
#    'date': 2010,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '122126',
#    'title': 'Jason Bourne ',
#    'date': 2016,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '194044',
#    'title': 'Looper ',
#    'date': 2012,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '142823',
#    'title': 'The Revenant ',
#    'date': 2015,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '205557',
#    'title': 'Red Sparrow',
#    'date': 2018,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1}],
#  [{'id': '85564',
#    'title': 'The Black Panther ',
#    'date': 1921,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '182404',
#    'title': 'The Black Panther ',
#    'date': 1977,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '204974',
#    'title': 'Black Panther',
#    'date': 2018,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '76130',
#    'title': 'Prince ',
#    'date': 1969,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '120552',
#    'title': 'Goodbye Solo',
#    'date': 2008,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1}],
#  [{'id': '180904',
#    'title': 'Soul Food ',
#    'date': 1997,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '174924',
#    'title': 'Two Can Play That Game',
#    'date': 2001,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '197322',
#    'title': 'Fried Green Tomatoes',
#    'date': 1991,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '84798',
#    'title': 'Pretty Woman',
#    'date': 1990,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '138527',
#    'title': 'Some Kind of Wonderful ',
#    'date': 1987,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1}],
#  [{'id': '202190',
#    'title': 'The Shining ',
#    'date': 1980,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '76519',
#    'title': 'Cloverfield',
#    'date': 2008,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '85612',
#    'title': 'The Texas Chain Saw Massacre',
#    'date': 1974,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '130591',
#    'title': 'Friday the 13th ',
#    'date': 1980,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '99244',
#    'title': 'Halloween ',
#    'date': 1978,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '133249',
#    'title': 'Up ',
#    'date': 2009,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '82894',
#    'title': 'Frozen',
#    'date': 2013,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '165710',
#    'title': 'The Boss Baby',
#    'date': 2017,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '205695',
#    'title': 'Blockers',
#    'date': 2018,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1}],
#  [{'id': '99896',
#    'title': 'Spider-Man ',
#    'date': 2002,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '130234',
#    'title': 'Hostel ',
#    'date': 2005,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '103175',
#    'title': 'Freddy vs. Jason',
#    'date': 2003,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '81432',
#    'title': 'A Serbian Film',
#    'date': 2010,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '204419',
#    'title': 'Jigsaw',
#    'date': 2017,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '180482',
#    'title': 'The Green Inferno ',
#    'date': 2013,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1}],
#  [{'id': '150941',
#    'title': 'Moulin Rouge!',
#    'date': 2001,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '204651',
#    'title': 'The Greatest Showman',
#    'date': 2017,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '200654',
#    'title': 'Mermaids ',
#    'date': 1990,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '104180',
#    'title': 'La La Land ',
#    'date': 2016,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '84854',
#    'title': 'Beauty and the Beast ',
#    'date': 2017,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '163708',
#    'title': 'Beauty and the Beast ',
#    'date': 1992,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '107314',
#    'title': "Ocean's Eleven",
#    'date': 2001,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '120947',
#    'title': "Ocean's Twelve",
#    'date': 2004,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '171250',
#    'title': 'Fury ',
#    'date': 2012,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '107554',
#    'title': 'Inglourious Basterds',
#    'date': 2009,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '184350',
#    'title': 'The Fundamentals of Caring',
#    'date': 2016,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '88172',
#    'title': "It's Kind of a Funny Story ",
#    'date': 2010,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '104253',
#    'title': 'The Perks of Being a Wallflower ',
#    'date': None,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '127908',
#    'title': 'To the Bone ',
#    'date': None,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '88487',
#    'title': 'Juno',
#    'date': 2007,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '204477',
#    'title': "Nick and Norah's Infinite Playlist",
#    'date': None,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1}],
#  [{'id': '99910',
#    'title': 'Blazing Saddles',
#    'date': 1974,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '168892',
#    'title': 'Young Frankenstein',
#    'date': 1974,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '154844',
#    'title': 'Finding Nemo',
#    'date': 2003,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '123995',
#    'title': 'Bambi',
#    'date': 1942,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '162647',
#    'title': 'Finding Dory',
#    'date': 2016,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '84854',
#    'title': 'Beauty and the Beast ',
#    'date': 2017,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '180224',
#    'title': 'The Cabin in the Woods',
#    'date': None,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '118756',
#    'title': 'Zombie Apocalypse ',
#    'date': None,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '184738',
#    'title': 'Lost in Space ',
#    'date': 1998,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '79062',
#    'title': 'Alien ',
#    'date': 1979,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '92826',
#    'title': 'E.T. the Extra-Terrestrial',
#    'date': 1982,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '179514',
#    'title': 'Stay ',
#    'date': 2013,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '161498',
#    'title': 'Toy Story 3',
#    'date': 2010,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '120520',
#    'title': 'Where the Red Fern Grows ',
#    'date': 1974,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '129416',
#    'title': 'The Fault in Our Stars ',
#    'date': 2014,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '121366',
#    'title': 'The Pianist ',
#    'date': 2002,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '148231',
#    'title': 'Jurassic Park ',
#    'date': 1993,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '79815',
#    'title': "We're Back! A Dinosaur's Story ",
#    'date': 1993,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '90248',
#    'title': 'Jurassic World',
#    'date': 2015,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '101158',
#    'title': 'Jurassic Park',
#    'date': None,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '81492',
#    'title': 'Dinosaur ',
#    'date': 2000,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '194202',
#    'title': 'The Land Before Time',
#    'date': 1988,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '186352',
#    'title': 'Enough ',
#    'date': 2002,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '157231',
#    'title': 'Double Jeopardy ',
#    'date': 1999,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1}],
#  [{'id': '108301',
#    'title': "Big Momma's House",
#    'date': 2000,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '138962',
#    'title': 'Bad Moms',
#    'date': 2016,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '204455',
#    'title': 'A Bad Moms Christmas',
#    'date': 2017,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '178502',
#    'title': 'Ted ',
#    'date': 2012,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1}],
#  [{'id': '204419',
#    'title': 'Jigsaw',
#    'date': 2017,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '204334',
#    'title': 'Happy Death Day ',
#    'date': 2017,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '89213',
#    'title': 'Jaws ',
#    'date': None,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '137503',
#    'title': 'Jaws: The Revenge',
#    'date': 1987,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '103896',
#    'title': 'House of 1000 Corpses',
#    'date': 2003,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '150829',
#    'title': 'Hostel ',
#    'date': 2011,
#    'suggested': 1,
#    'seen': 2,
#    'liked': 1},
#   {'id': '183910',
#    'title': 'Purge ',
#    'date': 2012,
#    'suggested': 1,
#    'seen': 2,
#    'liked': 1},
#   {'id': '153346',
#    'title': 'Insidious ',
#    'date': 2011,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '115463',
#    'title': 'Saw ',
#    'date': 2004,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '148222',
#    'title': 'The Human Centipede ',
#    'date': 2009,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '187028',
#    'title': 'It ',
#    'date': 2017,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '184418',
#    'title': 'Get Out',
#    'date': 2017,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '183910',
#    'title': 'Purge ',
#    'date': 2012,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '129036',
#    'title': 'Transformers ',
#    'date': 2007,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '106233',
#    'title': 'Jumanji',
#    'date': 1995,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '123015',
#    'title': 'The Proposal ',
#    'date': 2009,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '183169',
#    'title': 'Resident Evil ',
#    'date': 2002,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '181069',
#    'title': 'Resident Evil: The Final Chapter',
#    'date': 2016,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '94687',
#    'title': 'Underworld ',
#    'date': 2003,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '154247',
#    'title': 'Total Recall ',
#    'date': 2012,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '188939',
#    'title': 'Hitch ',
#    'date': 2005,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '185139',
#    'title': 'The Notebook',
#    'date': 2004,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '122202',
#    'title': 'The Tao of Steve',
#    'date': 2000,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '186635',
#    'title': 'Amélie',
#    'date': 2001,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '163150',
#    'title': 'Chocolat ',
#    'date': 2000,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '119884',
#    'title': 'Without a Paddle',
#    'date': 2004,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1}],
#  [{'id': '141214',
#    'title': 'In Dreams ',
#    'date': 1999,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '150891',
#    'title': 'Premonition ',
#    'date': 2004,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '141210',
#    'title': 'The Blind Side ',
#    'date': 2009,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '194237',
#    'title': 'Shutter Island ',
#    'date': 2010,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '112719',
#    'title': 'Gone Girl ',
#    'date': 2014,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '139048',
#    'title': 'The Girl on the Train ',
#    'date': 2016,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1}],
#  [{'id': '115908',
#    'title': '50 First Dates',
#    'date': 2004,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '159132',
#    'title': "Bridget Jones's Baby",
#    'date': 2016,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '188939',
#    'title': 'Hitch ',
#    'date': 2005,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '202175',
#    'title': 'Just Friends',
#    'date': 2005,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '100030',
#    'title': 'Friends with Benefits ',
#    'date': 2011,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '113213',
#    'title': 'I Love You, Man',
#    'date': 2009,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '112585',
#    'title': 'The Cider House Rules ',
#    'date': 1999,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '152789',
#    'title': 'Ant-Man ',
#    'date': 2015,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '180899',
#    'title': 'National Treasure ',
#    'date': 2004,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '149348',
#    'title': 'The Mummy ',
#    'date': 1999,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '173785',
#    'title': 'Get Hard',
#    'date': 2015,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '143062',
#    'title': "Child's Play ",
#    'date': 1988,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '153733',
#    'title': 'Saw ',
#    'date': 2003,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '204974',
#    'title': 'Black Panther',
#    'date': 2018,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '205163',
#    'title': 'Avengers: Infinity War',
#    'date': 2018,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '200523',
#    'title': 'Ready Player One ',
#    'date': 2018,
#    'suggested': 0,
#    'seen': 0,
#    'liked': 1},
#   {'id': '205695',
#    'title': 'Blockers',
#    'date': 2018,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1}],
#  [{'id': '153733',
#    'title': 'Saw ',
#    'date': 2003,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '203424',
#    'title': 'The Silence of the Lambs ',
#    'date': 1991,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '199831',
#    'title': 'Superbad ',
#    'date': 2007,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '135571',
#    'title': 'The Hangover',
#    'date': 2009,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '138962',
#    'title': 'Bad Moms',
#    'date': 2016,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '204455',
#    'title': 'A Bad Moms Christmas',
#    'date': 2017,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '204508',
#    'title': 'Father Figures',
#    'date': 2017,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '204974',
#    'title': 'Black Panther',
#    'date': 2018,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '147250',
#    'title': 'Coming to America',
#    'date': 1988,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '191672',
#    'title': 'Life ',
#    'date': 1999,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '78958',
#    'title': 'Norbit',
#    'date': 2007,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '133444',
#    'title': 'The Original Kings of Comedy',
#    'date': 2000,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '81162',
#    'title': 'Friday ',
#    'date': 1995,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '149514',
#    'title': 'Friday ',
#    'date': None,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '125213',
#    'title': 'Rounders ',
#    'date': 1998,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '127606',
#    'title': 'The Hustler ',
#    'date': 1961,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '150957',
#    'title': 'Casino ',
#    'date': 1995,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '109558',
#    'title': 'The Gambler ',
#    'date': 2014,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '170059',
#    'title': 'Die Hard 2',
#    'date': 1990,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '148871',
#    'title': 'Armageddon ',
#    'date': 1997,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '193168',
#    'title': 'Rush Hour ',
#    'date': 1998,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '144959',
#    'title': 'The Expendables ',
#    'date': 1989,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '139492',
#    'title': 'The Rock ',
#    'date': 1996,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '171914',
#    'title': 'Con Air',
#    'date': 1997,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '187028',
#    'title': 'It ',
#    'date': 2017,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '204334',
#    'title': 'Happy Death Day ',
#    'date': 2017,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '86414',
#    'title': 'Children of the Corn ',
#    'date': 1984,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '204419',
#    'title': 'Jigsaw',
#    'date': 2017,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1}],
#  [{'id': '187778',
#    'title': 'Liar Liar',
#    'date': 1997,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '166052',
#    'title': 'The Mask ',
#    'date': 1994,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '122385',
#    'title': 'Dumb and Dumber',
#    'date': 1994,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '150501',
#    'title': 'The Truman Show',
#    'date': 1998,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1}],
#  [{'id': '140066',
#    'title': 'Bridesmaids ',
#    'date': 2011,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '204331',
#    'title': 'Girls Trip',
#    'date': 2017,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '156698',
#    'title': 'White Chicks',
#    'date': 2004,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '193754',
#    'title': 'The Longest Yard ',
#    'date': 2005,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1}],
#  [{'id': '150887',
#    'title': "Ender's Game ",
#    'date': 2013,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '77293',
#    'title': 'A Wrinkle in Time ',
#    'date': None,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '204895',
#    'title': 'Peter Rabbit',
#    'date': 2018,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1}],
#  [{'id': '83552',
#    'title': 'Jumanji ',
#    'date': 2017,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '93521',
#    'title': 'Harry Potter ',
#    'date': None,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '169419',
#    'title': 'Thor: Ragnarok',
#    'date': 2017,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '177160',
#    'title': 'Justice League ',
#    'date': 2017,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '205054',
#    'title': '12 Strong',
#    'date': 2018,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '204899',
#    'title': 'Insidious: The Last Key',
#    'date': 2018,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '205547',
#    'title': 'I Can Only Imagine',
#    'date': 2018,
#    'suggested': 0,
#    'seen': 0,
#    'liked': 1},
#   {'id': '176326',
#    'title': 'Fifty Shades Freed ',
#    'date': 2018,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1}],
#  [{'id': '138341',
#    'title': 'Support Your Local Sheriff!',
#    'date': 1969,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '103867',
#    'title': 'Gunfight at the O.K. Corral ',
#    'date': 1957,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '180251',
#    'title': 'Tombstone ',
#    'date': 1993,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '113729',
#    'title': 'The Man Who Shot Liberty Valance',
#    'date': 1962,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '118762',
#    'title': '21 Jump Street ',
#    'date': 2012,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '133128',
#    'title': '22 Jump Street',
#    'date': 2014,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '205435',
#    'title': 'Game Night',
#    'date': 2018,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '138962',
#    'title': 'Bad Moms',
#    'date': 2016,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '204455',
#    'title': 'A Bad Moms Christmas',
#    'date': 2017,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '131244',
#    'title': 'Sisters ',
#    'date': 2015,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '201091',
#    'title': 'Mean Girls',
#    'date': 2004,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '152847',
#    'title': 'How to Lose a Guy in 10 Days',
#    'date': 2003,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '119090',
#    'title': 'Never Been Kissed',
#    'date': 1999,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '201259',
#    'title': "You've Got Mail",
#    'date': 1998,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '122021',
#    'title': 'Closer ',
#    'date': 2004,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '189406',
#    'title': 'Domino ',
#    'date': 2005,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '117364',
#    'title': 'Gandhi ',
#    'date': 1982,
#    'suggested': 0,
#    'seen': 0,
#    'liked': 1},
#   {'id': '126337',
#    'title': 'Anywhere but Here ',
#    'date': 1999,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '121751',
#    'title': 'Sexy Beast',
#    'date': 2000,
#    'suggested': 0,
#    'seen': 0,
#    'liked': 1}],
#  [{'id': '161313',
#    'title': 'Die Hard',
#    'date': 1988,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '101794',
#    'title': 'Lethal Weapon',
#    'date': 1987,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '204466',
#    'title': 'Atomic Blonde',
#    'date': 2017,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '198791',
#    'title': 'Brick Mansions',
#    'date': 2014,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '183050',
#    'title': 'Lucy ',
#    'date': 2014,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '205557',
#    'title': 'Red Sparrow',
#    'date': 2018,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1}],
#  [],
#  [{'id': '161313',
#    'title': 'Die Hard',
#    'date': 1988,
#    'suggested': 0,
#    'seen': 2,
#    'liked': 1},
#   {'id': '195979',
#    'title': 'Baby Driver ',
#    'date': 2017,
# ...
#    'date': 2016,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '189079',
#    'title': 'Pacific Rim ',
#    'date': None,
#    'suggested': 0,
#    'seen': 0,
#    'liked': 1},
#   {'id': '151350',
#    'title': 'Hellboy ',
#    'date': 2004,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '155044',
#    'title': 'Hellboy II: The Golden Army',
#    'date': 2008,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '197213',
#    'title': 'Interstellar ',
#    'date': 2014,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '79062',
#    'title': 'Alien ',
#    'date': 1979,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '96281',
#    'title': 'Star Wars: Episode VIII – The Last Jedi',
#    'date': 2017,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '138311',
#    'title': 'Life ',
#    'date': 2017,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '90486',
#    'title': 'Aliens ',
#    'date': 1986,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '149519',
#    'title': 'Prometheus ',
#    'date': 2012,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1}],
#  [{'id': '160772',
#    'title': 'The Good Dinosaur',
#    'date': 2015,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '133249',
#    'title': 'Up ',
#    'date': 2009,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '175121',
#    'title': 'The Lego Movie',
#    'date': 2014,
#    'suggested': 0,
#    'seen': 1,
#    'liked': 1},
#   {'id': '82923',
#    'title': 'Minions ',
#    'date': 2015,
#    'suggested': 1,
#    'seen': 1,
#    'liked': 1},
#   {'id': '161498',
#    'title': 'Toy Story 3',
#    'date': 2010,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1}],
#  [{'id': '159503',
#    'title': 'Passengers ',
#    'date': 2016,
#    'suggested': 1,
#    'seen': 0,
#    'liked': 1},
#   {'id': '121123',
#    'title': 'Silver Linings Playbook',
#    'date': 2012,
#    'suggested': 0,
#    'seen': 0,
#    'liked': 1}],
#  ...]
# Bad pipe message: %s [b"%\xc2\x95\x83\x00k\x88\x9d:\xa0\xb2(\xef\xe1e\xf1~_\x00\x00|\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0/\x00\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\\xc0`\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0#\xc0'\x00g\x00@\xc0\n\xc0\x14\x009\x008\xc0\t\xc0\x13\x003\x002\x00\x9d\xc0\xa1\xc0\x9d\xc0Q\x00\x9c\xc0\xa0\xc0\x9c\xc0P\x00=\x00<\x005\x00/\x00\x9a\x00\x99\xc0\x07\xc0\x11\x00\x96\x00\x05\x00\xff\x01\x00\x00j\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x000\x00.\x04\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08\t\x08\n\x08\x0b", b'\x08\x05\x08\x06\x04\x01\x05']
# Bad pipe message: %s [b'\x8a\xd4\xc1c\xf2\x8a\xd9\x9e\xc13\xa5\xd8\x16\x94V~\xbb\xff\x00\x00\xa6\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0/\x00\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\\xc0`\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0s\xc0w\x00\xc4\x00\xc3\xc0#', b'\x00g\x00@\xc0r\xc0v\x00\xbe\x00\xbd\xc0\n\xc0\x14\x009\x008\x00\x88\x00\x87\xc0\t\xc0\x13\x003\x002\x00\x9a\x00\x99\x00E\x00D\xc0\x07\xc0\x11\xc0\x08\xc0\x12\x00\x16\x00\x13\x00\x9d\xc0\xa1\xc0\x9d\xc0Q\x00\x9c\xc0\xa0\xc0\x9c\xc0P\x00=\x00\xc0\x00<\x00\xba\x005\x00\x84\x00/\x00\x96\x00A\x00\x05\x00\n\x00\xff\x01\x00\x00j\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x000\x00.\x04\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08\t\x08\n\x08\x0b\x08\x04\x08\x05\x08\x06\x04\x01\x05\x01\x06\x01\x03\x03\x02\x03\x03\x01\x02', b'', b'\x02']
# Bad pipe message: %s [b'']
# Bad pipe message: %s [b'\x05\x02\x06']
# Bad pipe message: %s [b"k'\xd1\x90\x91\x9fE\xf34\xdcn\xd5\x0cQ\x88\xad\xc2Z\x00\x00>\xc0\x14\xc0\n\x009\x008\x007\x006\xc0\x0f\xc0\x05\x005\xc0\x13\xc0\t\x003\x002\x001\x000\xc0\x0e\xc0\x04\x00/\x00\x9a\x00\x99\x00\x98\x00\x97\x00\x96\x00\x07\xc0\x11\xc0\x07\xc0\x0c\xc0\x02\x00\x05\x00\x04\x00\xff\x02\x01\x00\x00C\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x1c\x00\x1a\x00\x17\x00\x19\x00\x1c\x00\x1b\x00\x18\x00\x1a\x00\x16\x00\x0e\x00\r\x00\x0b\x00\x0c\x00\t\x00\n"]
# Bad pipe message: %s [b'', b'\x03\x03']
# Bad pipe message: %s [b'']
# Bad pipe message: %s [b'\xb4U^\xbf\x98\r>\x13\xa3^v\xaab`5\xca\x86^\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00']
# Bad pipe message: %s [b'', b'\x02']
# Bad pipe message: %s [b'\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x004\x00\x9b\x00F\xc0\x0e\xc0\x04\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00\x10\x00\r\xc0\x17\x00\x1b\xc0\r\xc0\x03\x00\n\x00\x15\x00\x12\x00\x0f\x00\x0c\x00\x1a\x00\t\x00\x14\x00\x11\x00\x19\x00\x08\x00\x06\x00\x17\x00\x03\xc0\x10\xc0\x06\xc0\x15']
# Bad pipe message: %s [b'\x05\x02\x06']
# Bad pipe message: %s [b'm\x89\xb4\x9eY\xbe\x93J\x05\xe2;\xd5T\xf0:\x8a\xcb\xd5\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x004\x00\x9b\x00F\xc0\x0e\xc0\x04\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00\x10\x00\r\xc0\x17\x00\x1b\xc0\r\xc0', b'\n\x00']
# Bad pipe message: %s [b'\x12\x00\x0f\x00\x0c\x00\x1a\x00\t\x00\x14\x00\x11\x00\x19\x00\x08\x00\x06\x00']
# Bad pipe message: %s [b'\x03\xc0\x10\xc0\x06\xc0\x15\xc0\x0b\xc0\x01\x00\x02\x00\x01\x00\xff\x02\x01\x00\x15\x03']
# Bad pipe message: %s [b"\xe8?\xb95\x8f\x9b\xab\xbd\x9c\xdb#\xa4\x10\xfbS\xd6\x00\xd2\x00\x00\x86\xc00\xc0,\xc0(\xc0$\xc0\x14\xc0\n\x00\xa5\x00\xa3\x00\xa1\x00\x9f\x00k\x00j\x00i\x00h\x009\x008\x007\x006\xc02\xc0.\xc0*\xc0&\xc0\x0f\xc0\x05\x00\x9d\x00=\x005\xc0/\xc0+\xc0'\xc0#\xc0\x13\xc0\t\x00\xa4\x00\xa2\x00\xa0\x00\x9e\x00g\x00@\x00?\x00>\x003\x002\x001\x000\xc01\xc0-\xc0)\xc0%\xc0\x0e\xc0\x04\x00\x9c\x00<\x00/\x00\x9a\x00\x99\x00\x98\x00\x97\x00\x96\x00\x07\xc0\x11\xc0\x07\xc0\x0c\xc0\x02\x00\x05\x00\x04\x00\xff\x02\x01\x00\x00g\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x1c\x00\x1a\x00\x17\x00\x19\x00\x1c\x00\x1b\x00\x18\x00\x1a\x00\x16\x00\x0e\x00\r\x00\x0b\x00\x0c\x00\t\x00\n\x00#\x00\x00\x00\r\x00 \x00\x1e\x06\x01\x06\x02\x06", b'\x01\x05', b'\x03', b'\x04\x02\x04', b'\x01\x03', b'\x03', b'\x02', b'\x03']
# Bad pipe message: %s [b"I\xd9\xea\xe4=G\xf33-\x910\xb6\xa9\x1akW\xb48\x00\x00\xf4\xc00\xc0,\xc0(\xc0$\xc0\x14\xc0\n\x00\xa5\x00\xa3\x00\xa1\x00\x9f\x00k\x00j\x00i\x00h\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00\xa7\x00m\x00:\x00\x89\xc02\xc0.\xc0*\xc0&\xc0\x0f\xc0\x05\x00\x9d\x00=\x005\x00\x84\xc0/\xc0+\xc0'\xc0#\xc0\x13\xc0\t\x00\xa4\x00\xa2\x00\xa0\x00\x9e\x00g\x00@\x00?\x00>\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x00\xa6\x00l\x004\x00\x9b\x00F\xc01\xc0-\xc0)\xc0%\xc0\x0e\xc0\x04\x00\x9c\x00<\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04"]
# Bad pipe message: %s [b'\xfc\xbd&\xbec<\xa8\x81\x8e\r\x92\x9b\xbe\xdb\x8b\xa40\xdd !\x1a4\x1c8\xa0\xf1\xe6w\x00\x979\x823\xc2\xf9\xdd\xa6\x97\x9d\xd7s\x952\x91\x06\x9c\xf1>\x15R\xf0\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00']
# Bad pipe message: %s [b'\x00\x00\x17\x00\x00\x00\r\x00\x1e\x00\x1c\x04\x03\x05\x03\x06\x03\x08\x07\x08\x08']
# Bad pipe message: %s [b'\x08\n\x08\x0b\x08\x04\x08', b'\x06\x04\x01\x05']
# Bad pipe message: %s [b'']
# Bad pipe message: %s [b"\xa2\xbbT\xb6q\x17\x1b\x9c\x99\x8e\xf0\xc57\xc7V\x98\x19\xe5\x00\x00|\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0/\x00\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\\xc0`\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0#\xc0'\x00g\x00@\xc0\n\xc0\x14\x009\x008\xc0\t\xc0\x13\x003\x002\x00\x9d\xc0\xa1\xc0\x9d\xc0Q\x00\x9c\xc0\xa0\xc0\x9c\xc0P\x00=\x00<\x005\x00/\x00\x9a\x00\x99\xc0\x07\xc0\x11\x00\x96\x00\x05\x00\xff\x01\x00\x00j\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17"]
# Bad pipe message: %s [b'']
# Bad pipe message: %s [b'\x03\x02\x03\x04\x00-\x00\x02\x01\x01\x003\x00&\x00$\x00\x1d\x00 \x7f\x046\xc2\xd3xd\xf1\xa1<x\x8d2R`\xca\xfeIiqOS']
# Bad pipe message: %s [b'\xa3M\xd4\xe5[\x06&\xa3%\xf9\xae\xf8\x85#mS\xc2\x98\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05']
# Bad pipe message: %s [b'i\xb0\xf00|\x07\xb5\xf5\x80\x11\x94\xbe\n4\xd7w/%\x00\x00>\xc0\x14\xc0\n\x009\x008\x007\x006\xc0\x0f\xc0\x05\x005\xc0\x13\xc0\t\x003\x002\x001\x000\xc0\x0e\xc0\x04\x00/\x00\x9a\x00\x99\x00\x98\x00\x97\x00\x96\x00\x07\xc0\x11\xc0\x07\xc0\x0c\xc0\x02\x00\x05\x00\x04\x00\xff\x02\x01\x00\x00C\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0']
# Bad pipe message: %s [b'.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x1c\x00\x1a\x00\x17\x00\x19\x00\x1c\x00\x1b\x00\x18\x00\x1a\x00\x16\x00\x0e\x00\r\x00\x0b\x00\x0c\x00\t\x00\n\x00#\x00']
# Bad pipe message: %s [b'k\xc7\xa9\x1ba~!\xe1\xe4\xd9\xc9\xa0\xdf\x07F\xa1\\3\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x004\x00\x9b\x00F\xc0\x0e\xc0\x04\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00\x10\x00\r\xc0\x17\x00\x1b\xc0\r\xc0\x03\x00\n\x00\x15\x00\x12\x00\x0f\x00\x0c\x00\x1a\x00\t\x00\x14\x00\x11\x00\x19\x00\x08\x00\x06\x00', b'\x03\xc0\x10\xc0\x06\xc0\x15\xc0\x0b\xc0\x01\x00\x02\x00\x01\x00\xff\x02\x01\x00\x00C']
# Bad pipe message: %s [b'\r\xef\x14\xb2\xbd\xa3e', b"ZS\xda\xb0\xbc\x07z\x13\xaf\x00\x00\xf4\xc00\xc0,\xc0(\xc0$\xc0\x14\xc0\n\x00\xa5\x00\xa3\x00\xa1\x00\x9f\x00k\x00j\x00i\x00h\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00\xa7\x00m\x00:\x00\x89\xc02\xc0.\xc0*\xc0&\xc0\x0f\xc0\x05\x00\x9d\x00=\x005\x00\x84\xc0/\xc0+\xc0'\xc0#\xc0\x13\xc0\t\x00\xa4\x00\xa2\x00\xa0\x00\x9e\x00g\x00@\x00?\x00>\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x00\xa6\x00l\x004\x00\x9b\x00F\xc01\xc0-\xc0)\xc0%\xc0\x0e\xc0\x04\x00\x9c\x00<\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00"]
# Bad pipe message: %s [b'\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00\x10\x00\r\xc0\x17\x00\x1b']
# Bad pipe message: %s [b'\xcc\xbaZ\x9e|\xf9gK\xf6\x9c\xa4\xb3N\x88\x12\x14L\xa7 \x85gS\x11\xd6&\x93-\xd6\x91}K\x7fD\xe4\x9b`~\xb7\xee\xf7X\xe3\xe0g\x07G\xddVf^\x82\x00\x08\x13\x02\x13']
# Bad pipe message: %s [b'\xda\xb7\xdc~V\xa1\\i\xe8\xdeT]\xeb|\xbex\xcaa \xad\x8brx-\xecZ\xf5?\x0b\xca\x90bk\x98\xddw\x83\xc4\x8a\xe0jv\xc7\xe6;?\xd9\x8c\xba\xe9\xde\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01']
# Bad pipe message: %s [b'\n']
# Bad pipe message: %s [b'\x91\x82\xc1\xa7m\x8c\xbeN\xea\xcc\xf9|\xa9%\x87A\xbc\xbd\x00\x00|\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0', b"\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\\xc0`\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0#\xc0'\x00g\x00@\xc0\n\xc0\x14\x009\x008\xc0\t\xc0"]
# Bad pipe message: %s [b'3\x002\x00\x9d\xc0\xa1\xc0\x9d\xc0Q\x00\x9c\xc0\xa0\xc0\x9c\xc0']
# Bad pipe message: %s [b'=\x00<\x005\x00/\x00\x9a\x00\x99\xc0\x07\xc0\x11\x00\x96\x00\x05\x00\xff\x01\x00\x00j\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00']
# Bad pipe message: %s [b"\xbdk\xec\x0c\xd9T\xb5*U#V\x1f\xd3\xdfJ\xb0\xfb\xae\x00\x00\xa6\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0/\x00\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\\xc0`\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0s\xc0w\x00\xc4\x00\xc3\xc0#\xc0'\x00g\x00@\xc0r\xc0v\x00\xbe\x00\xbd\xc0\n\xc0\x14\x009\x008\x00\x88\x00\x87\xc0\t\xc0\x13\x003\x002\x00\x9a\x00\x99\x00E\x00D\xc0\x07\xc0\x11\xc0\x08\xc0\x12\x00\x16\x00\x13\x00\x9d\xc0\xa1\xc0\x9d\xc0Q\x00\x9c\xc0\xa0\xc0\x9c\xc0P\x00=\x00\xc0\x00<\x00\xba\x005\x00\x84\x00/\x00\x96\x00A\x00\x05\x00\n\x00\xff\x01\x00\x00j\x00\x00\x00\x0e\x00\x0c\x00\x00\t"]
# Bad pipe message: %s [b'7.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x000\x00']
# Bad pipe message: %s [b'\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08\t\x08\n\x08\x0b\x08\x04\x08\x05\x08\x06\x04\x01\x05\x01\x06\x01\x03\x03\x02\x03\x03\x01\x02\x01\x03\x02\x02\x02\x04\x02\x05\x02\x06\x02']
# Bad pipe message: %s [b'\xea\xc1\x13\x86\xbb\xbbJ[i\x00\x86r m\x80*\x0c\x8f\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x004\x00\x9b\x00F\xc0\x0e\xc0\x04\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00\x10\x00\r\xc0\x17\x00\x1b\xc0\r\xc0\x03\x00\n\x00\x15\x00\x12\x00\x0f\x00\x0c\x00\x1a\x00\t\x00\x14\x00\x11\x00\x19\x00\x08\x00\x06\x00\x17\x00\x03\xc0\x10\xc0\x06\xc0\x15\xc0\x0b\xc0\x01\x00\x02\x00\x01\x00\xff\x02\x01\x00\x00C\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x1c\x00\x1a\x00\x17\x00\x19\x00\x1c\x00\x1b']
# Bad pipe message: %s [b'\xc8\xf6\t\x9e\x8d\xf3\xb6G\xca\xe7\x8ec\xc1Z\x85\xe9{\xcc\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x004\x00\x9b\x00F']
# Bad pipe message: %s [b"4\x15\x7f\xe5\x00]\xb6\x13Q\xd5\xb5\xcat\x9f`\x02\xc5\xab\x00\x00\x86\xc00\xc0,\xc0(\xc0$\xc0\x14\xc0\n\x00\xa5\x00\xa3\x00\xa1\x00\x9f\x00k\x00j\x00i\x00h\x009\x008\x007\x006\xc02\xc0.\xc0*\xc0&\xc0\x0f\xc0\x05\x00\x9d\x00=\x005\xc0/\xc0+\xc0'\xc0#\xc0\x13\xc0\t\x00\xa4\x00\xa2\x00\xa0\x00\x9e\x00g\x00@\x00?\x00>\x003\x002\x001\x000\xc01\xc0-\xc0)\xc0%\xc0\x0e\xc0\x04\x00\x9c\x00<\x00/\x00\x9a\x00\x99\x00\x98\x00\x97\x00\x96\x00\x07\xc0\x11\xc0\x07\xc0\x0c\xc0\x02\x00\x05\x00\x04\x00\xff\x02\x01\x00\x00g\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x1c\x00\x1a\x00\x17\x00\x19\x00\x1c\x00\x1b\x00\x18"]
# Bad pipe message: %s [b"\x82r\xb2T\xd31CQ\x18\xe8~\x04\x91\xbe\xc39T~\x00\x00\xf4\xc00\xc0,\xc0(\xc0$\xc0\x14\xc0\n\x00\xa5\x00\xa3\x00\xa1\x00\x9f\x00k\x00j\x00i\x00h\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00\xa7\x00m\x00:\x00\x89\xc02\xc0.\xc0*\xc0&\xc0\x0f\xc0\x05\x00\x9d\x00=\x005\x00\x84\xc0/\xc0+\xc0'\xc0#\xc0\x13\xc0\t\x00\xa4\x00\xa2\x00\xa0\x00\x9e\x00g\x00@\x00?\x00>\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x00\xa6\x00l\x004\x00\x9b\x00F\xc01\xc0-\xc0)\xc0%\xc0\x0e\xc0\x04\x00\x9c\x00<\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00\x10\x00\r\xc0\x17\x00\x1b\xc0\r\xc0\x03\x00\n\x00\x15\x00\x12\x00\x0f\x00\x0c\x00\x1a\x00\t\x00\x14\x00\x11\x00\x19\x00\x08\x00\x06\x00\x17\x00"]
# Bad pipe message: %s [b'\x10\xc0']
# Bad pipe message: %s [b'\x15\xc0\x0b\xc0\x01']

# %%
sampled_test_samples
# Out:
# [{'movieMentions': {'84273': 'Pineapple Express  (2008)',
#    '193168': 'Rush Hour  (1998)',
#    '148477': 'The Blues Brothers  (1980)',
#    '151102': 'Men in Black  (1997)',
#    '78340': 'Deadpool  (2016)'},
#   'respondentQuestions': [],
#   'messages': [{'timeOffset': 0,
#     'text': 'Hello! How are you?',
#     'senderWorkerId': 975,
#     'messageId': 204871,
#     'entity': ['<http://dbpedia.org/resource/Hello>',
#      '<http://dbpedia.org/resource/How_(TV_series)>'],
#     'entity_name': ['Hello!', 'How'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': []},
#    {'timeOffset': 5,
#     'text': 'Hi I am good',
#     'senderWorkerId': 976,
#     'messageId': 204872,
#     'entity': ['<http://dbpedia.org/resource/Hi_Records>',
#      '<http://dbpedia.org/resource/Goods>'],
#     'entity_name': ['Hi', 'good'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': []},
#    {'timeOffset': 8,
#     'text': 'How are you',
#     'senderWorkerId': 976,
#     'messageId': 204873,
#     'entity': ['<http://dbpedia.org/resource/How_(TV_series)>'],
#     'entity_name': ['How'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': []},
#    {'timeOffset': 35,
#     'text': "I'm fine. Do you have any good suggestions for a good movie?",
#     'senderWorkerId': 975,
#     'messageId': 204874,
#     'entity': ["<http://dbpedia.org/resource/I'm_Fine>",
#      '<http://dbpedia.org/resource/Do>',
#      '<http://dbpedia.org/resource/Goods>',
#      '<http://dbpedia.org/resource/Spelling_suggestion>',
#      '<http://dbpedia.org/resource/Good_Movie>'],
#     'entity_name': ["I'm fine", 'Do', 'good', 'suggestions', 'good movie'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['movie', 'suggestions', 'fine']},
#    {'timeOffset': 57,
#     'text': 'What kinds of movies do you like? Do you like dramatic movies?',
#     'senderWorkerId': 976,
#     'messageId': 204875,
#     'entity': ['<http://dbpedia.org/resource/String_theory>',
#      '<http://dbpedia.org/resource/Natural_kind>',
#      '<http://dbpedia.org/resource/Do>',
#      '<http://dbpedia.org/resource/Drama>'],
#     'entity_name': ['What', 'kinds', 'Do', 'dramatic'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['movies', 'dramatic', 'kinds']},
#    {'timeOffset': 85,
#     'text': 'I love action and funny movies, so I looking for something that combines the two,',
#     'senderWorkerId': 975,
#     'messageId': 204876,
#     'entity': ['<http://dbpedia.org/resource/Love_Action_(I_Believe_in_Love)>',
#      '<http://dbpedia.org/resource/Humour>',
#      '<http://dbpedia.org/resource/Combine_harvester>'],
#     'entity_name': ['love action', 'funny', 'combines'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['movies', 'love', 'funny', 'action', 'combines']},
#    {'timeOffset': 112,
#     'text': 'Do you like @84273 ?',
#     'senderWorkerId': 976,
#     'messageId': 204877,
#     'entity': ['<http://dbpedia.org/resource/Do>'],
#     'entity_name': ['Do'],
#     'movie': ['<http://dbpedia.org/resource/Pineapple_Express_(film)>'],
#     'movie_name': ['Pineapple Express (2008)'],
#     'word_name': ['pineapple', 'express']},
#    {'timeOffset': 135,
#     'text': 'You may like @193168 .',
#     'senderWorkerId': 976,
#     'messageId': 204878,
#     'entity': ['<http://dbpedia.org/resource/Israel>'],
#     'entity_name': ['You'],
#     'movie': ['<http://dbpedia.org/resource/Rush_Hour_(1998_film)>'],
#     'movie_name': ['Rush Hour (1998)'],
#     'word_name': ['hour', 'rush']},
#    {'timeOffset': 139,
#     'text': 'I have heard about it, but have never seen it. What is it about?',
#     'senderWorkerId': 975,
#     'messageId': 204879,
#     'entity': ['<http://dbpedia.org/resource/String_theory>'],
#     'entity_name': ['What'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['heard']},
#    {'timeOffset': 196,
#     'text': '@84273 is about two slackers that witness a murder. It is hilarious!',
#     'senderWorkerId': 976,
#     'messageId': 204880,
#     'entity': ['<http://dbpedia.org/resource/Slacker>',
#      '<http://dbpedia.org/resource/Witness>',
#      '<http://dbpedia.org/resource/Murder>',
#      '<http://dbpedia.org/resource/Wikipedia>'],
#     'entity_name': ['slackers', 'witness', 'murder', 'It'],
#     'movie': ['<http://dbpedia.org/resource/Pineapple_Express_(film)>'],
#     'movie_name': ['Pineapple Express (2008)'],
#     'word_name': ['witness', 'express', 'pineapple', 'hilarious', 'murder']},
#    {'timeOffset': 220,
#     'text': 'You might love @78340 !',
#     'senderWorkerId': 976,
#     'messageId': 204881,
#     'entity': ['<http://dbpedia.org/resource/Israel>',
#      '<http://dbpedia.org/resource/Love>'],
#     'entity_name': ['You', 'love'],
#     'movie': ['<http://dbpedia.org/resource/Deadpool_(film)>'],
#     'movie_name': ['Deadpool (2016)'],
#     'word_name': ['love', 'deadpool']},
#    {'timeOffset': 226,
#     'text': 'That does so really funny. And that would be the perfect movie for today.',
#     'senderWorkerId': 975,
#     'messageId': 204882,
#     'entity': ['<http://dbpedia.org/resource/That>',
#      '<http://dbpedia.org/resource/Humour>',
#      '<http://dbpedia.org/resource/And>',
#      '<http://dbpedia.org/resource/Perfect_graph>',
#      '<http://dbpedia.org/resource/Present>'],
#     'entity_name': ['That', 'funny', 'And', 'perfect', 'today'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['movie', 'funny', 'perfect']},
#    {'timeOffset': 229,
#     'text': 'That is full of action and comedy.',
#     'senderWorkerId': 976,
#     'messageId': 204883,
#     'entity': ['<http://dbpedia.org/resource/That>',
#      '<http://dbpedia.org/resource/Full_moon>',
#      '<http://dbpedia.org/resource/Action_film>',
#      '<http://dbpedia.org/resource/Comedy>'],
#     'entity_name': ['That', 'full', 'action', 'comedy'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['action', 'comedy']},
#    {'timeOffset': 254,
#     'text': 'The @148477 is a class too!',
#     'senderWorkerId': 976,
#     'messageId': 204884,
#     'entity': ['<http://dbpedia.org/resource/The>'],
#     'entity_name': ['The'],
#     'movie': ['<http://dbpedia.org/resource/The_Blues_Brothers_(film)>'],
#     'movie_name': ['The Blues Brothers (1980)'],
#     'word_name': ['class', 'brothers', 'blues']},
#    {'timeOffset': 261,
#     'text': 'Yes, I highly suggest @84273 !',
#     'senderWorkerId': 976,
#     'messageId': 204885,
#     'entity': ['<http://dbpedia.org/resource/Yes_(band)>',
#      '<http://dbpedia.org/resource/Enriched_uranium>'],
#     'entity_name': ['Yes', 'highly'],
#     'movie': ['<http://dbpedia.org/resource/Pineapple_Express_(film)>'],
#     'movie_name': ['Pineapple Express (2008)'],
#     'word_name': ['pineapple', 'express', 'highly']},
#    {'timeOffset': 265,
#     'text': 'I have heard so many things about Deadpool and from the ads it looks so good. Thank you. I just might give Deadpool a try.',
#     'senderWorkerId': 975,
#     'messageId': 204886,
#     'entity': ['<http://dbpedia.org/resource/Deadpool>',
#      '<http://dbpedia.org/resource/Advertising>',
#      '<http://dbpedia.org/resource/Goods>',
#      '<http://dbpedia.org/resource/Deadpool>'],
#     'entity_name': ['Deadpool', 'ads', 'good', 'Deadpool'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['heard', 'deadpool', 'ads']},
#    {'timeOffset': 268,
#     'text': "You won't be disappointed.",
#     'senderWorkerId': 976,
#     'messageId': 204887,
#     'entity': ['<http://dbpedia.org/resource/Israel>'],
#     'entity_name': ['You'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['wo', 'disappointed', "n't"]},
#    {'timeOffset': 285,
#     'text': 'That sounds great. I am so glad I could help you find a great movie to watch.',
#     'senderWorkerId': 976,
#     'messageId': 204888,
#     'entity': ['<http://dbpedia.org/resource/That>',
#      '<http://dbpedia.org/resource/Sound>',
#      '<http://dbpedia.org/resource/Great_Britain>',
#      '<http://dbpedia.org/resource/The_Glad_Products_Company>',
#      '<http://dbpedia.org/resource/Great_Britain>',
#      '<http://dbpedia.org/resource/Film>',
#      '<http://dbpedia.org/resource/Watch>'],
#     'entity_name': ['That',
#      'sounds',
#      'great',
#      'glad',
#      'great',
#      'movie',
#      'watch'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['glad', 'watch', 'movie', 'sounds']},
#    {'timeOffset': 308,
#     'text': 'I wonder if you have seen any of the movies I suggested?',
#     'senderWorkerId': 976,
#     'messageId': 204889,
#     'entity': ['<http://dbpedia.org/resource/Suggestion>'],
#     'entity_name': ['suggested'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['suggested', 'movies']},
#    {'timeOffset': 363,
#     'text': 'Have you see @148477 or @193168 ?',
#     'senderWorkerId': 976,
#     'messageId': 204890,
#     'entity': [],
#     'entity_name': [],
#     'movie': ['<http://dbpedia.org/resource/Rush_Hour_(1998_film)>',
#      '<http://dbpedia.org/resource/The_Blues_Brothers_(film)>'],
#     'movie_name': ['Rush Hour (1998)', 'The Blues Brothers (1980)'],
#     'word_name': ['hour', 'brothers', 'blues', 'rush']},
#    {'timeOffset': 393,
#     'text': 'Maybe you have seen @151102 ? That is a good movie too.',
#     'senderWorkerId': 976,
#     'messageId': 204891,
#     'entity': ['<http://dbpedia.org/resource/Maybe_(The_Chantels_song)>',
#      '<http://dbpedia.org/resource/That>',
#      '<http://dbpedia.org/resource/Good_Movie>'],
#     'entity_name': ['Maybe', 'That', 'good movie'],
#     'movie': ['<http://dbpedia.org/resource/Men_in_Black_(1997_film)>'],
#     'movie_name': ['Men in Black (1997)'],
#     'word_name': ['movie', 'black']},
#    {'timeOffset': 414,
#     'text': 'I think you need to agree you have seen one I suggested. :)',
#     'senderWorkerId': 976,
#     'messageId': 204892,
#     'entity': ['<http://dbpedia.org/resource/Suggestion>'],
#     'entity_name': ['suggested'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['suggested', 'agree']}],
#   'conversationId': '20291',
#   'respondentWorkerId': 976,
#   'initiatorWorkerId': 975,
#   'initiatorQuestions': []},
#  {'movieMentions': {'149543': 'Life of the Party  (2018)',
#    '170119': 'The Sixth Sense (1999)',
#    '204895': 'Peter Rabbit (2018)',
#    '154844': 'Finding Nemo (2003)',
#    '122604': 'Coco  (2017)',
#    '204974': 'Black Panther (2018)',
#    '162647': 'Finding Dory (2016)'},
#   'respondentQuestions': {'149543': {'suggested': 1, 'seen': 1, 'liked': 1},
#    '170119': {'suggested': 1, 'seen': 1, 'liked': 1},
#    '204895': {'suggested': 0, 'seen': 1, 'liked': 1},
#    '154844': {'suggested': 1, 'seen': 1, 'liked': 1},
#    '122604': {'suggested': 0, 'seen': 0, 'liked': 0},
#    '204974': {'suggested': 1, 'seen': 1, 'liked': 1},
#    '162647': {'suggested': 0, 'seen': 1, 'liked': 1}},
#   'messages': [{'timeOffset': 0,
#     'text': 'hello!',
#     'senderWorkerId': 1008,
#     'messageId': 209821,
#     'entity': [],
#     'entity_name': [],
#     'movie': [],
#     'movie_name': [],
#     'word_name': []},
#    {'timeOffset': 37,
#     'text': 'Do you know of any family friendly movies?',
#     'senderWorkerId': 1008,
#     'messageId': 209822,
#     'entity': ['<http://dbpedia.org/resource/Do>',
#      '<http://dbpedia.org/resource/Family-friendly>'],
#     'entity_name': ['Do', 'family friendly'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['family', 'friendly', 'movies']},
#    {'timeOffset': 45,
#     'text': 'Good Morning have you seen  @170119',
#     'senderWorkerId': 1022,
#     'messageId': 209823,
#     'entity': ['<http://dbpedia.org/resource/Good_Friday>',
#      '<http://dbpedia.org/resource/Morning>'],
#     'entity_name': ['Good', 'Morning'],
#     'movie': ['<http://dbpedia.org/resource/The_Sixth_Sense>'],
#     'movie_name': ['The Sixth Sense (1999)'],
#     'word_name': ['sense', 'morning', 'sixth']},
#    {'timeOffset': 76,
#     'text': 'Yes, but it is too scary for my children.',
#     'senderWorkerId': 1008,
#     'messageId': 209824,
#     'entity': ['<http://dbpedia.org/resource/Yes_(band)>'],
#     'entity_name': ['Yes'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['scary', 'children']},
#    {'timeOffset': 89,
#     'text': 'something like, @204895',
#     'senderWorkerId': 1008,
#     'messageId': 209825,
#     'entity': [],
#     'entity_name': [],
#     'movie': ['<http://dbpedia.org/resource/Peter_Rabbit_(film)>'],
#     'movie_name': ['Peter Rabbit (2018)'],
#     'word_name': ['peter', 'rabbit']},
#    {'timeOffset': 99,
#     'text': 'we saw that and it was cute',
#     'senderWorkerId': 1008,
#     'messageId': 209826,
#     'entity': ['<http://dbpedia.org/resource/Cuteness>'],
#     'entity_name': ['cute'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['cute']},
#    {'timeOffset': 124,
#     'text': 'A old classic will be @154844',
#     'senderWorkerId': 1022,
#     'messageId': 209827,
#     'entity': ['<http://dbpedia.org/resource/British_Classic_Races>'],
#     'entity_name': ['classic'],
#     'movie': ['<http://dbpedia.org/resource/Finding_Nemo>'],
#     'movie_name': ['Finding Nemo (2003)'],
#     'word_name': ['finding', 'classic']},
#    {'timeOffset': 157,
#     'text': 'oh yes, and @162647 !',
#     'senderWorkerId': 1008,
#     'messageId': 209828,
#     'entity': [],
#     'entity_name': [],
#     'movie': ['<http://dbpedia.org/resource/Finding_Dory>'],
#     'movie_name': ['Finding Dory (2016)'],
#     'word_name': ['finding', 'dory']},
#    {'timeOffset': 163,
#     'text': 'I saw @204895 with my daughter she loved it',
#     'senderWorkerId': 1022,
#     'messageId': 209829,
#     'entity': ['<http://dbpedia.org/resource/Love_of_God>'],
#     'entity_name': ['loved'],
#     'movie': ['<http://dbpedia.org/resource/Peter_Rabbit_(film)>'],
#     'movie_name': ['Peter Rabbit (2018)'],
#     'word_name': ['peter', 'rabbit', 'daughter', 'loved']},
#    {'timeOffset': 165,
#     'text': "we've seen them, but they are great",
#     'senderWorkerId': 1008,
#     'messageId': 209830,
#     'entity': ['<http://dbpedia.org/resource/Great_Britain>'],
#     'entity_name': ['great'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': []},
#    {'timeOffset': 201,
#     'text': 'Have you seen @122604 ? We are waiting for it to come to netflix',
#     'senderWorkerId': 1008,
#     'messageId': 209831,
#     'entity': ['<http://dbpedia.org/resource/Poland>',
#      '<http://dbpedia.org/resource/Waiting_staff>',
#      '<http://dbpedia.org/resource/Netflix>'],
#     'entity_name': ['We', 'waiting', 'netflix'],
#     'movie': ['<http://dbpedia.org/resource/Coco_(2017_film)>'],
#     'movie_name': ['Coco (2017)'],
#     'word_name': ['waiting', 'coco', 'netflix']},
#    {'timeOffset': 253,
#     'text': "I haven't seen that one @204974  was a great movie to see with the family",
#     'senderWorkerId': 1022,
#     'messageId': 209832,
#     'entity': ['<http://dbpedia.org/resource/Great_Britain>',
#      '<http://dbpedia.org/resource/Film>',
#      '<http://dbpedia.org/resource/Family_(biology)>'],
#     'entity_name': ['great', 'movie', 'family'],
#     'movie': ['<http://dbpedia.org/resource/Black_Panther_(film)>'],
#     'movie_name': ['Black Panther (2018)'],
#     'word_name': ['movie', 'family', 'black', "n't", 'panther']},
#    {'timeOffset': 281,
#     'text': "Really? I wouldn't think that was family appropriate",
#     'senderWorkerId': 1008,
#     'messageId': 209833,
#     'entity': ['<http://dbpedia.org/resource/Really_(TV_channel)>',
#      '<http://dbpedia.org/resource/Family_(biology)>'],
#     'entity_name': ['Really', 'family'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['family', "n't"]},
#    {'timeOffset': 288,
#     'text': 'I will have to look into it',
#     'senderWorkerId': 1008,
#     'messageId': 209834,
#     'entity': [],
#     'entity_name': [],
#     'movie': [],
#     'movie_name': [],
#     'word_name': []},
#    {'timeOffset': 370,
#     'text': "Well you wouldn't if you haven't seen it but good movie",
#     'senderWorkerId': 1022,
#     'messageId': 209835,
#     'entity': ['<http://dbpedia.org/resource/Well>',
#      '<http://dbpedia.org/resource/Good_Movie>'],
#     'entity_name': ['Well', 'good movie'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['movie', "n't"]},
#    {'timeOffset': 391,
#     'text': 'okay, thanks!',
#     'senderWorkerId': 1008,
#     'messageId': 209836,
#     'entity': [],
#     'entity_name': [],
#     'movie': [],
#     'movie_name': [],
#     'word_name': []},
#    {'timeOffset': 408,
#     'text': 'thanks for your help. Have a great day!',
#     'senderWorkerId': 1008,
#     'messageId': 209837,
#     'entity': ['<http://dbpedia.org/resource/Great_Day_(1945_film)>'],
#     'entity_name': ['great day'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['day']},
#    {'timeOffset': 452,
#     'text': 'How about that @149543',
#     'senderWorkerId': 1022,
#     'messageId': 209838,
#     'entity': ['<http://dbpedia.org/resource/How_(TV_series)>'],
#     'entity_name': ['How'],
#     'movie': ['<http://dbpedia.org/resource/Life_of_the_Party_(2018_film)>'],
#     'movie_name': ['Life of the Party (2018)'],
#     'word_name': ['party', 'life']}],
#   'conversationId': '20995',
#   'respondentWorkerId': 1022,
#   'initiatorWorkerId': 1008,
#   'initiatorQuestions': {'149543': {'suggested': 1, 'seen': 2, 'liked': 2},
#    '170119': {'suggested': 1, 'seen': 1, 'liked': 0},
#    '204895': {'suggested': 0, 'seen': 1, 'liked': 1},
#    '154844': {'suggested': 1, 'seen': 1, 'liked': 1},
#    '122604': {'suggested': 0, 'seen': 2, 'liked': 2},
#    '204974': {'suggested': 1, 'seen': 0, 'liked': 1},
#    '162647': {'suggested': 0, 'seen': 1, 'liked': 1}}},
#  {'movieMentions': {'76620': 'The Shaggy Dog  (1959)',
#    '77293': 'A Wrinkle in Time ',
#    '205744': 'Isle Of Dogs (2018)',
#    '204651': 'The Greatest Showman (2017)',
#    '163184': 'Escape to Witch Mountain  (1975)'},
#   'respondentQuestions': {'76620': {'suggested': 1, 'seen': 1, 'liked': 1},
#    '77293': {'suggested': 1, 'seen': 0, 'liked': 1},
#    '205744': {'suggested': 1, 'seen': 0, 'liked': 2},
#    '204651': {'suggested': 0, 'seen': 1, 'liked': 1},
#    '163184': {'suggested': 1, 'seen': 1, 'liked': 1}},
#   'messages': [{'timeOffset': 0,
#     'text': 'Hi, how are you today?',
#     'senderWorkerId': 996,
#     'messageId': 226141,
#     'entity': ['<http://dbpedia.org/resource/Hi_Records>',
#      '<http://dbpedia.org/resource/Holocene>'],
#     'entity_name': ['Hi', 'today'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': []},
#    {'timeOffset': 14,
#     'text': "Hi. I'm good. How are you?",
#     'senderWorkerId': 1049,
#     'messageId': 226142,
#     'entity': ['<http://dbpedia.org/resource/Hi_Records>',
#      "<http://dbpedia.org/resource/I'm_Good_(Blaque_song)>",
#      '<http://dbpedia.org/resource/How_(TV_series)>'],
#     'entity_name': ['Hi', "I'm good", 'How'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': []},
#    {'timeOffset': 28,
#     'text': "I'm good. What kind of movies are you looking for?",
#     'senderWorkerId': 996,
#     'messageId': 226143,
#     'entity': ["<http://dbpedia.org/resource/I'm_Good_(Blaque_song)>",
#      '<http://dbpedia.org/resource/String_theory>',
#      '<http://dbpedia.org/resource/Kindness>'],
#     'entity_name': ["I'm good", 'What', 'kind'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['movies']},
#    {'timeOffset': 67,
#     'text': 'I like family movies like @204651',
#     'senderWorkerId': 1049,
#     'messageId': 226144,
#     'entity': ['<http://dbpedia.org/resource/Family_(biology)>'],
#     'entity_name': ['family'],
#     'movie': ['<http://dbpedia.org/resource/The_Greatest_Showman>'],
#     'movie_name': ['The Greatest Showman (2017)'],
#     'word_name': ['family', 'showman', 'movies']},
#    {'timeOffset': 113,
#     'text': 'Do you like older Disney films like @76620? Or @163184?',
#     'senderWorkerId': 996,
#     'messageId': 226145,
#     'entity': ['<http://dbpedia.org/resource/Do>',
#      '<http://dbpedia.org/resource/The_Walt_Disney_Company>',
#      '<http://dbpedia.org/resource/Or_(heraldry)>'],
#     'entity_name': ['Do', 'Disney', 'Or'],
#     'movie': ['<http://dbpedia.org/resource/The_Shaggy_Dog_(1959_film)>',
#      '<http://dbpedia.org/resource/Escape_to_Witch_Mountain_(1975_film)>'],
#     'movie_name': ['The Shaggy Dog (1959)', 'Escape to Witch Mountain (1975)'],
#     'word_name': ['films',
#      'dog',
#      'shaggy',
#      'disney',
#      'witch',
#      'mountain',
#      'escape']},
#    {'timeOffset': 146,
#     'text': "I've seen those. They are pretty good!",
#     'senderWorkerId': 1049,
#     'messageId': 226146,
#     'entity': ['<http://dbpedia.org/resource/Kotoko_(musician)>',
#      '<http://dbpedia.org/resource/They>',
#      '<http://dbpedia.org/resource/Physical_attractiveness>',
#      '<http://dbpedia.org/resource/Goods>'],
#     'entity_name': ["I've", 'They', 'pretty', 'good'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['pretty']},
#    {'timeOffset': 194,
#     'text': 'Or for something newer, you might like @77293.',
#     'senderWorkerId': 996,
#     'messageId': 226147,
#     'entity': ['<http://dbpedia.org/resource/Or_(heraldry)>',
#      '<http://dbpedia.org/resource/Contemporary_R&B>'],
#     'entity_name': ['Or', 'newer'],
#     'movie': ['<http://dbpedia.org/resource/A_Wrinkle_in_Time_(2018_film)>'],
#     'movie_name': ['A Wrinkle in Time'],
#     'word_name': ['time', 'wrinkle']},
#    {'timeOffset': 231,
#     'text': "I haven't seen that yet, but I have read the book and I really liked it. I'll have to watch the movie.",
#     'senderWorkerId': 1049,
#     'messageId': 226148,
#     'entity': ['<http://dbpedia.org/resource/Reading>',
#      "<http://dbpedia.org/resource/I'll>",
#      '<http://dbpedia.org/resource/Watch>'],
#     'entity_name': ['read', "I'll", 'watch'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['movie', 'book', 'watch', 'read', "n't"]},
#    {'timeOffset': 262,
#     'text': 'Yeah, I loved that book when I was a kid! I hope they make movies of the sequels.',
#     'senderWorkerId': 996,
#     'messageId': 226149,
#     'entity': ['<http://dbpedia.org/resource/Yeah!_(Usher_song)>',
#      '<http://dbpedia.org/resource/Love_of_God>',
#      '<http://dbpedia.org/resource/Goat>',
#      '<http://dbpedia.org/resource/I_Hope_(Gabby_Barrett_song)>',
#      '<http://dbpedia.org/resource/Sequel>'],
#     'entity_name': ['Yeah', 'loved', 'kid', 'I hope', 'sequels'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['hope',
#      'movies',
#      'yeah',
#      'book',
#      'kid',
#      'loved',
#      'sequels']},
#    {'timeOffset': 278,
#     'text': 'That would be great!',
#     'senderWorkerId': 1049,
#     'messageId': 226150,
#     'entity': ['<http://dbpedia.org/resource/That>',
#      '<http://dbpedia.org/resource/Great_(1975_film)>'],
#     'entity_name': ['That', 'great!'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': []},
#    {'timeOffset': 301,
#     'text': 'Thank you for the suggestions!',
#     'senderWorkerId': 1049,
#     'messageId': 226151,
#     'entity': ['<http://dbpedia.org/resource/Spelling_suggestion>'],
#     'entity_name': ['suggestions'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['suggestions']},
#    {'timeOffset': 305,
#     'text': 'Another newer family film is @205744. Have you seen that yet?',
#     'senderWorkerId': 996,
#     'messageId': 226152,
#     'entity': ['<http://dbpedia.org/resource/Another_(novel)>',
#      '<http://dbpedia.org/resource/Contemporary_R&B>',
#      '<http://dbpedia.org/resource/Family_(biology)>'],
#     'entity_name': ['Another', 'newer', 'family'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['family', 'isle', 'dogs', 'film']},
#    {'timeOffset': 319,
#     'text': "No, I haven't seen that one.",
#     'senderWorkerId': 1049,
#     'messageId': 226153,
#     'entity': ['<http://dbpedia.org/resource/Bermuda_Triangle>'],
#     'entity_name': ['No'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ["n't"]},
#    {'timeOffset': 349,
#     'text': "Hope this helps you find what you're looking for.",
#     'senderWorkerId': 996,
#     'messageId': 226154,
#     'entity': ['<http://dbpedia.org/resource/Hope>',
#      '<http://dbpedia.org/resource/Reliability_of_Wikipedia>'],
#     'entity_name': ['Hope', 'helps'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['helps', 'hope']},
#    {'timeOffset': 360,
#     'text': 'It helps a lot. Thank you!',
#     'senderWorkerId': 1049,
#     'messageId': 226155,
#     'entity': ['<http://dbpedia.org/resource/Wikipedia>',
#      '<http://dbpedia.org/resource/Reliability_of_Wikipedia>',
#      '<http://dbpedia.org/resource/Land_lot>'],
#     'entity_name': ['It', 'helps', 'lot'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['helps', 'lot']},
#    {'timeOffset': 373,
#     'text': 'Have a great day! Bye',
#     'senderWorkerId': 1049,
#     'messageId': 226156,
#     'entity': ['<http://dbpedia.org/resource/Great_Day_(1945_film)>',
#      '<http://dbpedia.org/resource/Bye_(sports)>'],
#     'entity_name': ['great day', 'Bye'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['day', 'bye']}],
#   'conversationId': '22815',
#   'respondentWorkerId': 996,
#   'initiatorWorkerId': 1049,
#   'initiatorQuestions': {'76620': {'suggested': 1, 'seen': 1, 'liked': 1},
#    '77293': {'suggested': 1, 'seen': 0, 'liked': 1},
#    '205744': {'suggested': 1, 'seen': 0, 'liked': 2},
#    '204651': {'suggested': 0, 'seen': 1, 'liked': 1},
#    '163184': {'suggested': 1, 'seen': 1, 'liked': 1}}},
#  {'movieMentions': {'114785': 'Little Shop of Horrors  (1986)',
#    '159885': 'The Incredibles (2004)',
#    '205724': 'Incredibles 2 (2018)',
#    '122604': 'Coco  (2017)',
#    '111776': 'Super Troopers (2001)',
#    '93310': 'The Rocky Horror Picture Show (1975)',
#    '206076': 'Ralph Breaks the Internet (2018)',
#    '97306': 'Into the Woods  (2014)',
#    '160690': 'Super Troopers 2 (2018)'},
#   'respondentQuestions': {'114785': {'suggested': 1, 'seen': 1, 'liked': 1},
#    '159885': {'suggested': 1, 'seen': 1, 'liked': 1},
#    '205724': {'suggested': 1, 'seen': 0, 'liked': 1},
#    '122604': {'suggested': 0, 'seen': 1, 'liked': 2},
#    '111776': {'suggested': 1, 'seen': 2, 'liked': 2},
#    '93310': {'suggested': 0, 'seen': 1, 'liked': 1},
#    '206076': {'suggested': 1, 'seen': 0, 'liked': 2},
#    '97306': {'suggested': 0, 'seen': 0, 'liked': 0},
#    '160690': {'suggested': 1, 'seen': 2, 'liked': 2}},
#   'messages': [{'timeOffset': 0,
#     'text': 'Hello, how are you?',
#     'senderWorkerId': 1009,
#     'messageId': 225075,
#     'entity': ['<http://dbpedia.org/resource/Hello_(Adele_song)>'],
#     'entity_name': ['Hello'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': []},
#    {'timeOffset': 26,
#     'text': "Glad it's Friday.",
#     'senderWorkerId': 1046,
#     'messageId': 225076,
#     'entity': ['<http://dbpedia.org/resource/The_Glad_Products_Company>',
#      '<http://dbpedia.org/resource/Friday>'],
#     'entity_name': ['Glad', 'Friday'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['glad', 'friday']},
#    {'timeOffset': 44,
#     'text': 'Yes, me too!',
#     'senderWorkerId': 1009,
#     'messageId': 225077,
#     'entity': ['<http://dbpedia.org/resource/Yes_(band)>'],
#     'entity_name': ['Yes'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': []},
#    {'timeOffset': 49,
#     'text': 'So many good part 2 movies coming out like @205724 and @160690',
#     'senderWorkerId': 1009,
#     'messageId': 225078,
#     'entity': ['<http://dbpedia.org/resource/SO>',
#      '<http://dbpedia.org/resource/Goods>',
#      '<http://dbpedia.org/resource/Second_Coming>'],
#     'entity_name': ['So', 'good', 'coming'],
#     'movie': ['<http://dbpedia.org/resource/Incredibles_2>',
#      '<http://dbpedia.org/resource/Super_Troopers_2>'],
#     'movie_name': ['Incredibles 2 (2018)', 'Super Troopers 2 (2018)'],
#     'word_name': ['movies', 'troopers', '2', 'coming', 'super']},
#    {'timeOffset': 56,
#     'text': 'We have a great indy theater here that plays @93310 every weekend.',
#     'senderWorkerId': 1046,
#     'messageId': 225079,
#     'entity': ['<http://dbpedia.org/resource/Poland>',
#      '<http://dbpedia.org/resource/Great_Britain>',
#      '<http://dbpedia.org/resource/Indianapolis_500>',
#      '<http://dbpedia.org/resource/Theatre>',
#      '<http://dbpedia.org/resource/Theatre>'],
#     'entity_name': ['We', 'great', 'indy', 'theater', 'plays'],
#     'movie': ['<http://dbpedia.org/resource/The_Rocky_Horror_Picture_Show>'],
#     'movie_name': ['The Rocky Horror Picture Show (1975)'],
#     'word_name': ['weekend',
#      'horror',
#      'indy',
#      'theater',
#      'rocky',
#      'plays',
#      'picture']},
#    {'timeOffset': 64,
#     'text': 'Have you seen @111776  or @159885',
#     'senderWorkerId': 1009,
#     'messageId': 225080,
#     'entity': [],
#     'entity_name': [],
#     'movie': ['<http://dbpedia.org/resource/The_Incredibles_(film_score)>',
#      '<http://dbpedia.org/resource/Super_Troopers>'],
#     'movie_name': ['The Incredibles (2004)', 'Super Troopers (2001)'],
#     'word_name': ['troopers', 'super', '2001']},
#    {'timeOffset': 74,
#     'text': 'Oh, wow... that would be nice to see in theatre...',
#     'senderWorkerId': 1009,
#     'messageId': 225081,
#     'entity': ['<http://dbpedia.org/resource/Seung-hwan_Oh>',
#      '<http://dbpedia.org/resource/Wow_(recording)>',
#      '<http://dbpedia.org/resource/Nice>',
#      '<http://dbpedia.org/resource/Theatre>'],
#     'entity_name': ['Oh', 'wow', 'nice', 'theatre'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['theatre', 'wow', 'nice']},
#    {'timeOffset': 83,
#     'text': "Loved The Incredibles. Can't wait for the sequel",
#     'senderWorkerId': 1046,
#     'messageId': 225082,
#     'entity': ['<http://dbpedia.org/resource/Loved_(film)>',
#      '<http://dbpedia.org/resource/The_Incredibles>',
#      "<http://dbpedia.org/resource/Can't_Wait>",
#      '<http://dbpedia.org/resource/Sequel>'],
#     'entity_name': ['Loved', 'Incredibles', "Can't wait", 'sequel'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['loved', 'sequel', "n't", 'wait']},
#    {'timeOffset': 91,
#     'text': 'Yes!! Me too.',
#     'senderWorkerId': 1009,
#     'messageId': 225083,
#     'entity': ['<http://dbpedia.org/resource/Armlock>',
#      '<http://dbpedia.org/resource/Methyl_group>'],
#     'entity_name': ['Yes!', 'Me'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': []},
#    {'timeOffset': 99,
#     'text': 'Also excited for @206076',
#     'senderWorkerId': 1009,
#     'messageId': 225084,
#     'entity': ['<http://dbpedia.org/resource/Also>',
#      '<http://dbpedia.org/resource/Excited_state>'],
#     'entity_name': ['Also', 'excited'],
#     'movie': ['<http://dbpedia.org/resource/Ralph_Breaks_the_Internet>'],
#     'movie_name': ['Ralph Breaks the Internet (2018)'],
#     'word_name': ['breaks', 'ralph', 'excited', 'internet']},
#    {'timeOffset': 103,
#     'text': 'Did you see @122604',
#     'senderWorkerId': 1046,
#     'messageId': 225085,
#     'entity': [],
#     'entity_name': [],
#     'movie': ['<http://dbpedia.org/resource/Coco_(2017_film)>'],
#     'movie_name': ['Coco (2017)'],
#     'word_name': ['coco']},
#    {'timeOffset': 109,
#     'text': 'Yes and I loved it!',
#     'senderWorkerId': 1009,
#     'messageId': 225086,
#     'entity': ['<http://dbpedia.org/resource/Yes_(band)>',
#      '<http://dbpedia.org/resource/Love_of_God>'],
#     'entity_name': ['Yes', 'loved'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['loved']},
#    {'timeOffset': 126,
#     'text': 'You made me think of @114785',
#     'senderWorkerId': 1009,
#     'messageId': 225087,
#     'entity': ['<http://dbpedia.org/resource/Israel>'],
#     'entity_name': ['You'],
#     'movie': ['<http://dbpedia.org/resource/Little_Shop_of_Horrors_(film)>'],
#     'movie_name': ['Little Shop of Horrors (1986)'],
#     'word_name': ['shop', 'horrors']},
#    {'timeOffset': 141,
#     'text': 'Have you seen that one?',
#     'senderWorkerId': 1009,
#     'messageId': 225088,
#     'entity': [],
#     'entity_name': [],
#     'movie': [],
#     'movie_name': [],
#     'word_name': []},
#    {'timeOffset': 147,
#     'text': 'My daughter was stage manager for a local production one year',
#     'senderWorkerId': 1046,
#     'messageId': 225089,
#     'entity': ['<http://dbpedia.org/resource/Wikimedia_Foundation>',
#      '<http://dbpedia.org/resource/Stage_management>',
#      '<http://dbpedia.org/resource/Local_government>',
#      '<http://dbpedia.org/resource/Record_producer>'],
#     'entity_name': ['My', 'stage manager', 'local', 'production'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['production', 'stage', 'local', 'daughter', 'manager']},
#    {'timeOffset': 158,
#     'text': "Wow, that's fantastic!",
#     'senderWorkerId': 1009,
#     'messageId': 225090,
#     'entity': ['<http://dbpedia.org/resource/Wow_(Kylie_Minogue_song)>',
#      '<http://dbpedia.org/resource/Fantasy>'],
#     'entity_name': ['Wow', 'fantastic'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['wow', 'fantastic']},
#    {'timeOffset': 169,
#     'text': 'Did you get to go on set?',
#     'senderWorkerId': 1009,
#     'messageId': 225091,
#     'entity': ['<http://dbpedia.org/resource/Set_(mathematics)>'],
#     'entity_name': ['set'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['set']},
#    {'timeOffset': 220,
#     'text': 'Not really. I helped iron costumes but that was about it. Speaking of musicals @97306 was surpsiingly good',
#     'senderWorkerId': 1046,
#     'messageId': 225092,
#     'entity': ['<http://dbpedia.org/resource/England>',
#      '<http://dbpedia.org/resource/Introduced_species>',
#      '<http://dbpedia.org/resource/Iron>',
#      '<http://dbpedia.org/resource/Costume>',
#      '<http://dbpedia.org/resource/Speech>',
#      '<http://dbpedia.org/resource/Musical_theatre>',
#      '<http://dbpedia.org/resource/Goods>'],
#     'entity_name': ['Not',
#      'helped',
#      'iron',
#      'costumes',
#      'Speaking',
#      'musicals',
#      'good'],
#     'movie': ['<http://dbpedia.org/resource/Into_the_Woods_(film)>'],
#     'movie_name': ['Into the Woods (2014)'],
#     'word_name': ['woods',
#      'musicals',
#      'speaking',
#      'costumes',
#      'iron',
#      'helped']},
#    {'timeOffset': 278,
#     'text': 'Oh, I never saw it, I heard it was annoying because that song came on over and over.. so I took my friends advice and avoided it lol',
#     'senderWorkerId': 1009,
#     'messageId': 225093,
#     'entity': ['<http://dbpedia.org/resource/Seung-hwan_Oh>',
#      '<http://dbpedia.org/resource/Annoyance>',
#      '<http://dbpedia.org/resource/Song>',
#      '<http://dbpedia.org/resource/Friends_Advice>',
#      '<http://dbpedia.org/resource/Triskaidekaphobia>',
#      '<http://dbpedia.org/resource/LOL>'],
#     'entity_name': ['Oh',
#      'annoying',
#      'song',
#      'friends advice',
#      'avoided',
#      'lol'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['avoided',
#      'friends',
#      'annoying',
#      'heard',
#      'song',
#      'lol',
#      'advice']},
#    {'timeOffset': 286,
#     'text': "Maybe I'll give it a try tho.",
#     'senderWorkerId': 1009,
#     'messageId': 225094,
#     'entity': ['<http://dbpedia.org/resource/Maybe_(The_Chantels_song)>',
#      "<http://dbpedia.org/resource/I'll>"],
#     'entity_name': ['Maybe', "I'll"],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['tho']},
#    {'timeOffset': 292,
#     'text': 'Thanks for the recommendations!',
#     'senderWorkerId': 1009,
#     'messageId': 225095,
#     'entity': ['<http://dbpedia.org/resource/Gratitude>'],
#     'entity_name': ['Thanks'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['recommendations']},
#    {'timeOffset': 298,
#     'text': 'nice chatting with you',
#     'senderWorkerId': 1046,
#     'messageId': 225096,
#     'entity': ['<http://dbpedia.org/resource/Nice>',
#      '<http://dbpedia.org/resource/Online_chat>'],
#     'entity_name': ['nice', 'chatting'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['nice', 'chatting']},
#    {'timeOffset': 298,
#     'text': 'Have a great day.  Bye for now.',
#     'senderWorkerId': 1009,
#     'messageId': 225097,
#     'entity': ['<http://dbpedia.org/resource/Great_Day_(1945_film)>',
#      '<http://dbpedia.org/resource/Bye_(sports)>'],
#     'entity_name': ['great day', 'Bye'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['day', 'bye']}],
#   'conversationId': '22683',
#   'respondentWorkerId': 1009,
#   'initiatorWorkerId': 1046,
#   'initiatorQuestions': {'114785': {'suggested': 1, 'seen': 1, 'liked': 1},
#    '159885': {'suggested': 0, 'seen': 1, 'liked': 1},
#    '205724': {'suggested': 0, 'seen': 0, 'liked': 1},
#    '122604': {'suggested': 0, 'seen': 2, 'liked': 2},
#    '111776': {'suggested': 1, 'seen': 0, 'liked': 2},
#    '93310': {'suggested': 0, 'seen': 2, 'liked': 2},
#    '206076': {'suggested': 1, 'seen': 0, 'liked': 2},
#    '97306': {'suggested': 0, 'seen': 1, 'liked': 1},
#    '160690': {'suggested': 1, 'seen': 0, 'liked': 2}}},
#  {'movieMentions': {'204974': 'Black Panther (2018)',
#    '135571': 'The Hangover (2009)',
#    '205163': 'Avengers: Infinity War (2018)',
#    '78874': 'Click  (2006)',
#    '204331': 'Girls Trip (2017)'},
#   'respondentQuestions': {'204974': {'suggested': 0, 'seen': 1, 'liked': 1},
#    '135571': {'suggested': 1, 'seen': 2, 'liked': 2},
#    '205163': {'suggested': 1, 'seen': 1, 'liked': 1},
#    '78874': {'suggested': 1, 'seen': 1, 'liked': 1},
#    '204331': {'suggested': 1, 'seen': 0, 'liked': 2}},
#   'messages': [{'timeOffset': 0,
#     'text': 'hello',
#     'senderWorkerId': 960,
#     'messageId': 206136,
#     'entity': [],
#     'entity_name': [],
#     'movie': [],
#     'movie_name': [],
#     'word_name': []},
#    {'timeOffset': 6,
#     'text': 'Hi!',
#     'senderWorkerId': 997,
#     'messageId': 206137,
#     'entity': ['<http://dbpedia.org/resource/Hi_Records>'],
#     'entity_name': ['Hi'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': []},
#    {'timeOffset': 17,
#     'text': "i'm open to any movie",
#     'senderWorkerId': 960,
#     'messageId': 206138,
#     'entity': ['<http://dbpedia.org/resource/Open_set>'],
#     'entity_name': ['open'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['movie']},
#    {'timeOffset': 23,
#     'text': 'What would you recommend?',
#     'senderWorkerId': 960,
#     'messageId': 206139,
#     'entity': ['<http://dbpedia.org/resource/String_theory>'],
#     'entity_name': ['What'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['recommend']},
#    {'timeOffset': 37,
#     'text': 'Have you seen @204331',
#     'senderWorkerId': 997,
#     'messageId': 206140,
#     'entity': [],
#     'entity_name': [],
#     'movie': ['<http://dbpedia.org/resource/Girls_Trip>'],
#     'movie_name': ['Girls Trip (2017)'],
#     'word_name': ['girls', 'trip']},
#    {'timeOffset': 47,
#     'text': 'i really loved @204974 and @205163',
#     'senderWorkerId': 960,
#     'messageId': 206141,
#     'entity': ['<http://dbpedia.org/resource/Love_of_God>'],
#     'entity_name': ['loved'],
#     'movie': ['<http://dbpedia.org/resource/Black_Panther_(film)>',
#      '<http://dbpedia.org/resource/Avengers:_Infinity_War>'],
#     'movie_name': ['Black Panther (2018)', 'Avengers: Infinity War (2018)'],
#     'word_name': ['black', 'loved', 'war', 'infinity', 'panther', 'avengers']},
#    {'timeOffset': 59,
#     'text': 'no, i have not seen it',
#     'senderWorkerId': 960,
#     'messageId': 206142,
#     'entity': [],
#     'entity_name': [],
#     'movie': [],
#     'movie_name': [],
#     'word_name': []},
#    {'timeOffset': 60,
#     'text': 'Both were great! You like Marvel?',
#     'senderWorkerId': 997,
#     'messageId': 206143,
#     'entity': ['<http://dbpedia.org/resource/Jan_Dirksz_Both>',
#      '<http://dbpedia.org/resource/Great_(1975_film)>',
#      '<http://dbpedia.org/resource/Israel>'],
#     'entity_name': ['Both', 'great!', 'You'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['marvel']},
#    {'timeOffset': 64,
#     'text': 'What is it about?',
#     'senderWorkerId': 960,
#     'messageId': 206144,
#     'entity': ['<http://dbpedia.org/resource/String_theory>'],
#     'entity_name': ['What'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': []},
#    {'timeOffset': 74,
#     'text': 'Of course i love Marvel movies!',
#     'senderWorkerId': 960,
#     'messageId': 206145,
#     'entity': ['<http://dbpedia.org/resource/OF>',
#      '<http://dbpedia.org/resource/Love>',
#      '<http://dbpedia.org/resource/Movies!>'],
#     'entity_name': ['Of', 'love', 'movies!'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['love', 'marvel', 'movies']},
#    {'timeOffset': 84,
#     'text': 'Girls going on a wild trip!',
#     'senderWorkerId': 997,
#     'messageId': 206146,
#     'entity': ['<http://dbpedia.org/resource/Wildlife>',
#      '<http://dbpedia.org/resource/Psychedelic_experience>'],
#     'entity_name': ['wild', 'trip'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['wild', 'girls', 'trip']},
#    {'timeOffset': 92,
#     'text': 'i also like Comedy movies like @78874',
#     'senderWorkerId': 960,
#     'messageId': 206147,
#     'entity': ['<http://dbpedia.org/resource/Comedy>'],
#     'entity_name': ['Comedy'],
#     'movie': ['<http://dbpedia.org/resource/Click_(2006_film)>'],
#     'movie_name': ['Click (2006)'],
#     'word_name': ['comedy', 'movies']},
#    {'timeOffset': 102,
#     'text': 'Kind of like @135571',
#     'senderWorkerId': 997,
#     'messageId': 206148,
#     'entity': ['<http://dbpedia.org/resource/Johann_Friedrich_Kind>'],
#     'entity_name': ['Kind'],
#     'movie': ['<http://dbpedia.org/resource/The_Hangover>'],
#     'movie_name': ['The Hangover (2009)'],
#     'word_name': ['hangover']},
#    {'timeOffset': 111,
#     'text': 'that movie sounds interesting',
#     'senderWorkerId': 960,
#     'messageId': 206149,
#     'entity': ['<http://dbpedia.org/resource/Sound>'],
#     'entity_name': ['sounds'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['movie', 'sounds']},
#    {'timeOffset': 114,
#     'text': 'Just with girls',
#     'senderWorkerId': 997,
#     'messageId': 206150,
#     'entity': ['<http://dbpedia.org/resource/Just>',
#      '<http://dbpedia.org/resource/Single-sex_education>'],
#     'entity_name': ['Just', 'girls'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['girls']},
#    {'timeOffset': 123,
#     'text': 'Yes, but those are girls',
#     'senderWorkerId': 960,
#     'messageId': 206151,
#     'entity': ['<http://dbpedia.org/resource/Yes_(band)>',
#      '<http://dbpedia.org/resource/Single-sex_education>'],
#     'entity_name': ['Yes', 'girls'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['girls']},
#    {'timeOffset': 131,
#     'text': 'i could try that one',
#     'senderWorkerId': 960,
#     'messageId': 206152,
#     'entity': [],
#     'entity_name': [],
#     'movie': [],
#     'movie_name': [],
#     'word_name': []},
#    {'timeOffset': 137,
#     'text': 'Thank you for helping me',
#     'senderWorkerId': 960,
#     'messageId': 206153,
#     'entity': ['<http://dbpedia.org/resource/Helping_behavior>'],
#     'entity_name': ['helping'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['helping']},
#    {'timeOffset': 143,
#     'text': 'Have a nice day',
#     'senderWorkerId': 960,
#     'messageId': 206154,
#     'entity': ['<http://dbpedia.org/resource/Nice>',
#      '<http://dbpedia.org/resource/Day>'],
#     'entity_name': ['nice', 'day'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['nice', 'day']},
#    {'timeOffset': 144,
#     'text': 'Yea no problem!',
#     'senderWorkerId': 997,
#     'messageId': 206155,
#     'entity': ['<http://dbpedia.org/resource/Yea_Football_Club>'],
#     'entity_name': ['Yea'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['yea']},
#    {'timeOffset': 153,
#     'text': "i'll enjoy my evening",
#     'senderWorkerId': 960,
#     'messageId': 206156,
#     'entity': ['<http://dbpedia.org/resource/Evening>'],
#     'entity_name': ['evening'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['evening', 'enjoy']},
#    {'timeOffset': 157,
#     'text': 'Have a good one bye!',
#     'senderWorkerId': 997,
#     'messageId': 206157,
#     'entity': ['<http://dbpedia.org/resource/Goods>',
#      '<http://dbpedia.org/resource/Glossary_of_tennis_terms>'],
#     'entity_name': ['good', 'bye'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['bye']},
#    {'timeOffset': 158,
#     'text': 'Good bye',
#     'senderWorkerId': 960,
#     'messageId': 206158,
#     'entity': ['<http://dbpedia.org/resource/Glossary_of_tennis_terms>'],
#     'entity_name': ['bye'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['bye']},
#    {'timeOffset': 159,
#     'text': 'Good bye',
#     'senderWorkerId': 960,
#     'messageId': 206159,
#     'entity': ['<http://dbpedia.org/resource/Glossary_of_tennis_terms>'],
#     'entity_name': ['bye'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['bye']},
#    {'timeOffset': 165,
#     'text': 'bye',
#     'senderWorkerId': 997,
#     'messageId': 206160,
#     'entity': ['<http://dbpedia.org/resource/Glossary_of_tennis_terms>'],
#     'entity_name': ['bye'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['bye']}],
#   'conversationId': '20652',
#   'respondentWorkerId': 997,
#   'initiatorWorkerId': 960,
#   'initiatorQuestions': {'204974': {'suggested': 0, 'seen': 1, 'liked': 1},
#    '135571': {'suggested': 1, 'seen': 1, 'liked': 1},
#    '205163': {'suggested': 0, 'seen': 1, 'liked': 1},
#    '78874': {'suggested': 0, 'seen': 1, 'liked': 1},
#    '204331': {'suggested': 1, 'seen': 0, 'liked': 1}}},
#  {'movieMentions': {'101780': 'Zathura  (2005)',
#    '83552': 'Jumanji  (2017)',
#    '162930': 'The BFG  (2016)',
#    '115290': 'Hook  (1991)',
#    '106233': 'Jumanji (1995)'},
#   'respondentQuestions': {'101780': {'suggested': 1, 'seen': 1, 'liked': 2},
#    '83552': {'suggested': 0, 'seen': 0, 'liked': 2},
#    '162930': {'suggested': 1, 'seen': 0, 'liked': 1},
#    '115290': {'suggested': 1, 'seen': 1, 'liked': 2},
#    '106233': {'suggested': 0, 'seen': 2, 'liked': 2}},
#   'messages': [{'timeOffset': 0,
#     'text': 'Hi, how are ya?',
#     'senderWorkerId': 1062,
#     'messageId': 219186,
#     'entity': ['<http://dbpedia.org/resource/Hi_Records>'],
#     'entity_name': ['Hi'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['ya']},
#    {'timeOffset': 1,
#     'text': 'hi',
#     'senderWorkerId': 1056,
#     'messageId': 219187,
#     'entity': [],
#     'entity_name': [],
#     'movie': [],
#     'movie_name': [],
#     'word_name': []},
#    {'timeOffset': 6,
#     'text': "i'm good how are you?",
#     'senderWorkerId': 1056,
#     'messageId': 219188,
#     'entity': ['<http://dbpedia.org/resource/Goods>'],
#     'entity_name': ['good'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': []},
#    {'timeOffset': 16,
#     'text': 'Great, thanks!',
#     'senderWorkerId': 1062,
#     'messageId': 219189,
#     'entity': ['<http://dbpedia.org/resource/Great>'],
#     'entity_name': ['Great'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': []},
#    {'timeOffset': 24,
#     'text': 'What kind of movies do you like?',
#     'senderWorkerId': 1062,
#     'messageId': 219190,
#     'entity': ['<http://dbpedia.org/resource/String_theory>',
#      '<http://dbpedia.org/resource/Kindness>'],
#     'entity_name': ['What', 'kind'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['movies']},
#    {'timeOffset': 24,
#     'text': "I've been watching 5 straight hours of chopped and need a movie to watch.",
#     'senderWorkerId': 1056,
#     'messageId': 219191,
#     'entity': ["<http://dbpedia.org/resource/I've_Sound>",
#      '<http://dbpedia.org/resource/Whale_watching>',
#      '<http://dbpedia.org/resource/Heterosexuality>',
#      '<http://dbpedia.org/resource/Chopped_and_screwed>',
#      '<http://dbpedia.org/resource/Watch>'],
#     'entity_name': ["I've", 'watching', 'straight', 'chopped', 'watch'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['chopped',
#      'movie',
#      'hours',
#      'watch',
#      '5',
#      'watching',
#      'straight']},
#    {'timeOffset': 34,
#     'text': 'haha! Chopped is an awesome show!',
#     'senderWorkerId': 1062,
#     'messageId': 219192,
#     'entity': ['<http://dbpedia.org/resource/Haha_(entertainer)>',
#      '<http://dbpedia.org/resource/Awesome>'],
#     'entity_name': ['haha', 'awesome'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['awesome', 'haha', 'chopped']},
#    {'timeOffset': 43,
#     'text': 'Yes, I love it.',
#     'senderWorkerId': 1056,
#     'messageId': 219193,
#     'entity': ['<http://dbpedia.org/resource/Yes_(band)>',
#      '<http://dbpedia.org/resource/Love>'],
#     'entity_name': ['Yes', 'love'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['love']},
#    {'timeOffset': 61,
#     'text': 'Any good adventure movies like @106233 ?',
#     'senderWorkerId': 1056,
#     'messageId': 219194,
#     'entity': ['<http://dbpedia.org/resource/Goods>'],
#     'entity_name': ['good'],
#     'movie': ['<http://dbpedia.org/resource/Jumanji>'],
#     'movie_name': ['Jumanji (1995)'],
# ...
#     'entity_name': ['Thanks'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': []}],
#   'conversationId': '22583',
#   'respondentWorkerId': 1088,
#   'initiatorWorkerId': 1087,
#   'initiatorQuestions': {'152883': {'suggested': 1, 'seen': 0, 'liked': 2},
#    '178096': {'suggested': 1, 'seen': 0, 'liked': 2},
#    '142895': {'suggested': 0, 'seen': 1, 'liked': 1},
#    '108945': {'suggested': 1, 'seen': 0, 'liked': 2},
#    '111063': {'suggested': 1, 'seen': 0, 'liked': 2},
#    '178885': {'suggested': 0, 'seen': 1, 'liked': 1},
#    '119662': {'suggested': 0, 'seen': 1, 'liked': 1},
#    '189705': {'suggested': 0, 'seen': 1, 'liked': 1},
#    '190543': {'suggested': 1, 'seen': 1, 'liked': 2},
#    '168758': {'suggested': 0, 'seen': 1, 'liked': 1},
#    '123083': {'suggested': 0, 'seen': 1, 'liked': 1},
#    '106588': {'suggested': 0, 'seen': 1, 'liked': 1}}},
#  {'movieMentions': {'180131': 'The Freshman  (1990)',
#    '163619': "Ferris Bueller's Day Off (1986)",
#    '154329': 'License to Drive (1988)',
#    '130379': 'Richie Rich  (1994)'},
#   'respondentQuestions': {'180131': {'suggested': 1, 'seen': 0, 'liked': 1},
#    '163619': {'suggested': 0, 'seen': 1, 'liked': 1},
#    '154329': {'suggested': 1, 'seen': 0, 'liked': 1},
#    '130379': {'suggested': 0, 'seen': 1, 'liked': 2}},
#   'messages': [{'timeOffset': 0,
#     'text': 'Hi there!',
#     'senderWorkerId': 1035,
#     'messageId': 219698,
#     'entity': ['<http://dbpedia.org/resource/Hi_Records>'],
#     'entity_name': ['Hi'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': []},
#    {'timeOffset': 3,
#     'text': 'How are you?',
#     'senderWorkerId': 1035,
#     'messageId': 219699,
#     'entity': ['<http://dbpedia.org/resource/How_(TV_series)>'],
#     'entity_name': ['How'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': []},
#    {'timeOffset': 16,
#     'text': "I'm well and yourself?",
#     'senderWorkerId': 1034,
#     'messageId': 219700,
#     'entity': ['<http://dbpedia.org/resource/Wikipedia>'],
#     'entity_name': ["I'm"],
#     'movie': [],
#     'movie_name': [],
#     'word_name': []},
#    {'timeOffset': 36,
#     'text': 'Doing good.  What kind of movies do you like?',
#     'senderWorkerId': 1035,
#     'messageId': 219701,
#     'entity': ['<http://dbpedia.org/resource/Doing_(album)>',
#      '<http://dbpedia.org/resource/Goods>',
#      '<http://dbpedia.org/resource/String_theory>',
#      '<http://dbpedia.org/resource/Kindness>'],
#     'entity_name': ['Doing', 'good', 'What', 'kind'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['movies']},
#    {'timeOffset': 57,
#     'text': 'I really like movies like @163619',
#     'senderWorkerId': 1034,
#     'messageId': 219702,
#     'entity': [],
#     'entity_name': [],
#     'movie': ["<http://dbpedia.org/resource/Ferris_Bueller's_Day_Off>"],
#     'movie_name': ["Ferris Bueller's Day Off (1986)"],
#     'word_name': ['ferris', 'day', 'movies']},
#    {'timeOffset': 67,
#     'text': "I've seen it like ten times!",
#     'senderWorkerId': 1034,
#     'messageId': 219703,
#     'entity': ["<http://dbpedia.org/resource/I've_Sound>",
#      '<http://dbpedia.org/resource/10>',
#      '<http://dbpedia.org/resource/Cap_(sport)>'],
#     'entity_name': ["I've", 'ten', 'times'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['times']},
#    {'timeOffset': 74,
#     'text': 'That is an excellent movie, one of my all-time favorites.',
#     'senderWorkerId': 1035,
#     'messageId': 219704,
#     'entity': ['<http://dbpedia.org/resource/That>',
#      '<http://dbpedia.org/resource/Wikipedia>',
#      '<http://dbpedia.org/resource/Bookmark_(digital)>'],
#     'entity_name': ['That', 'excellent', 'favorites'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['movie', 'excellent', 'favorites']},
#    {'timeOffset': 98,
#     'text': 'How about @154329 ?  It is a comedy about a kid who gets into messes.',
#     'senderWorkerId': 1035,
#     'messageId': 219705,
#     'entity': ['<http://dbpedia.org/resource/How_(TV_series)>',
#      '<http://dbpedia.org/resource/Wikipedia>',
#      '<http://dbpedia.org/resource/Comedy_film>',
#      '<http://dbpedia.org/resource/Goat>',
#      '<http://dbpedia.org/resource/Mess>'],
#     'entity_name': ['How', 'It', 'comedy', 'kid', 'messes'],
#     'movie': ['<http://dbpedia.org/resource/License_to_Drive>'],
#     'movie_name': ['License to Drive (1988)'],
#     'word_name': ['messes', 'kid', 'license', 'comedy', 'drive']},
#    {'timeOffset': 116,
#     'text': "Oh nice. Haven't even heard of it",
#     'senderWorkerId': 1034,
#     'messageId': 219706,
#     'entity': ['<http://dbpedia.org/resource/Seung-hwan_Oh>',
#      '<http://dbpedia.org/resource/Nice>'],
#     'entity_name': ['Oh', 'nice'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['nice', 'heard', "n't"]},
#    {'timeOffset': 127,
#     'text': 'Sounds a little like @130379',
#     'senderWorkerId': 1034,
#     'messageId': 219707,
#     'entity': ['<http://dbpedia.org/resource/Sound>'],
#     'entity_name': ['Sounds'],
#     'movie': ['<http://dbpedia.org/resource/Richie_Rich_(film)>'],
#     'movie_name': ['Richie Rich (1994)'],
#     'word_name': ['richie', 'sounds', 'rich']},
#    {'timeOffset': 132,
#     'text': 'But without the money haha',
#     'senderWorkerId': 1034,
#     'messageId': 219708,
#     'entity': ['<http://dbpedia.org/resource/BUT>',
#      '<http://dbpedia.org/resource/Money>',
#      '<http://dbpedia.org/resource/Haha_(entertainer)>'],
#     'entity_name': ['But', 'money', 'haha'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['haha', 'money']},
#    {'timeOffset': 145,
#     'text': 'If you like Matthew Broderick, there was a movie called @180131 that I loved.',
#     'senderWorkerId': 1035,
#     'messageId': 219709,
#     'entity': ['<http://dbpedia.org/resource/If_(magazine)>',
#      '<http://dbpedia.org/resource/Matthew_Broderick>',
#      '<http://dbpedia.org/resource/Call_to_the_bar>',
#      '<http://dbpedia.org/resource/Love_of_God>'],
#     'entity_name': ['If', 'Matthew Broderick', 'called', 'loved'],
#     'movie': ['<http://dbpedia.org/resource/The_Freshman_(1990_film)>'],
#     'movie_name': ['The Freshman (1990)'],
#     'word_name': ['movie',
#      'called',
#      'broderick',
#      'matthew',
#      'loved',
#      'freshman']},
#    {'timeOffset': 162,
#     'text': "Haven't seen that. Great suggestion though!",
#     'senderWorkerId': 1034,
#     'messageId': 219710,
#     'entity': ['<http://dbpedia.org/resource/Great>',
#      '<http://dbpedia.org/resource/Suggestion>'],
#     'entity_name': ['Great', 'suggestion'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['suggestion', "n't"]},
#    {'timeOffset': 168,
#     'text': 'Gonna go check it out thanks!',
#     'senderWorkerId': 1034,
#     'messageId': 219711,
#     'entity': ['<http://dbpedia.org/resource/Going-to_future>'],
#     'entity_name': ['Gonna'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['check', 'gon']},
#    {'timeOffset': 171,
#     'text': "No, @154329 is totally different.  Haha!  The kid is older.  It's one of the Coreys, I think Cory Haim.",
#     'senderWorkerId': 1035,
#     'messageId': 219712,
#     'entity': ['<http://dbpedia.org/resource/Bermuda_Triangle>',
#      '<http://dbpedia.org/resource/Totally>',
#      '<http://dbpedia.org/resource/Haha_(entertainer)>',
#      '<http://dbpedia.org/resource/The_Kid_(artist)>',
#      '<http://dbpedia.org/resource/Wikipedia>',
#      '<http://dbpedia.org/resource/Haim>'],
#     'entity_name': ['No', 'totally', 'Haha', 'The kid', 'It', 'Haim'],
#     'movie': ['<http://dbpedia.org/resource/License_to_Drive>'],
#     'movie_name': ['License to Drive (1988)'],
#     'word_name': ['kid', 'haha', 'license', 'drive', 'totally']},
#    {'timeOffset': 172,
#     'text': 'Have a good one!',
#     'senderWorkerId': 1034,
#     'messageId': 219713,
#     'entity': ['<http://dbpedia.org/resource/Goods>'],
#     'entity_name': ['good'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': []},
#    {'timeOffset': 178,
#     'text': 'You, too!',
#     'senderWorkerId': 1035,
#     'messageId': 219714,
#     'entity': ['<http://dbpedia.org/resource/Israel>'],
#     'entity_name': ['You'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': []},
#    {'timeOffset': 182,
#     'text': 'Cool gonna look it up. Thanks',
#     'senderWorkerId': 1034,
#     'messageId': 219715,
#     'entity': ['<http://dbpedia.org/resource/Cool>',
#      '<http://dbpedia.org/resource/Beer>'],
#     'entity_name': ['Cool', 'Thanks'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['gon', 'cool']}],
#   'conversationId': '22038',
#   'respondentWorkerId': 1035,
#   'initiatorWorkerId': 1034,
#   'initiatorQuestions': {'180131': {'suggested': 1, 'seen': 0, 'liked': 1},
#    '163619': {'suggested': 0, 'seen': 1, 'liked': 1},
#    '154329': {'suggested': 1, 'seen': 0, 'liked': 1},
#    '130379': {'suggested': 0, 'seen': 1, 'liked': 2}}},
#  {'movieMentions': {'115908': '50 First Dates (2004)',
#    '191440': 'Shallow Hal (2001)',
#    '181301': 'Billy Madison (1995)',
#    '157394': 'The Wedding Singer (1998)',
#    '136983': 'Ghostbusters (1984)'},
#   'respondentQuestions': {'115908': {'suggested': 0, 'seen': 1, 'liked': 1},
#    '191440': {'suggested': 1, 'seen': 1, 'liked': 1},
#    '181301': {'suggested': 0, 'seen': 1, 'liked': 1},
#    '157394': {'suggested': 1, 'seen': 1, 'liked': 1},
#    '136983': {'suggested': 1, 'seen': 1, 'liked': 1}},
#   'messages': [{'timeOffset': 0,
#     'text': 'Hi! How are you?',
#     'senderWorkerId': 976,
#     'messageId': 205300,
#     'entity': ['<http://dbpedia.org/resource/Hi_Records>',
#      '<http://dbpedia.org/resource/How_(TV_series)>'],
#     'entity_name': ['Hi', 'How'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': []},
#    {'timeOffset': 20,
#     'text': "I'm good and you?",
#     'senderWorkerId': 959,
#     'messageId': 205301,
#     'entity': ["<http://dbpedia.org/resource/I'm_Good_(Blaque_song)>"],
#     'entity_name': ["I'm good"],
#     'movie': [],
#     'movie_name': [],
#     'word_name': []},
#    {'timeOffset': 33,
#     'text': 'Just looking for some good movies to watch.',
#     'senderWorkerId': 959,
#     'messageId': 205302,
#     'entity': ['<http://dbpedia.org/resource/Just>',
#      '<http://dbpedia.org/resource/Goods>',
#      '<http://dbpedia.org/resource/Film>',
#      '<http://dbpedia.org/resource/Watch>'],
#     'entity_name': ['Just', 'good', 'movies', 'watch'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['watch', 'movies']},
#    {'timeOffset': 34,
#     'text': 'I am looking for a comedy. I really like @157394 .',
#     'senderWorkerId': 976,
#     'messageId': 205303,
#     'entity': ['<http://dbpedia.org/resource/Comedy>'],
#     'entity_name': ['comedy'],
#     'movie': ['<http://dbpedia.org/resource/The_Wedding_Singer>'],
#     'movie_name': ['The Wedding Singer (1998)'],
#     'word_name': ['singer', 'comedy', 'wedding']},
#    {'timeOffset': 47,
#     'text': 'Oh I see. What do you like?',
#     'senderWorkerId': 976,
#     'messageId': 205304,
#     'entity': ['<http://dbpedia.org/resource/Seung-hwan_Oh>',
#      '<http://dbpedia.org/resource/String_theory>'],
#     'entity_name': ['Oh', 'What'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': []},
#    {'timeOffset': 52,
#     'text': 'I love that movie.  Have you seen @181301',
#     'senderWorkerId': 959,
#     'messageId': 205305,
#     'entity': ['<http://dbpedia.org/resource/Love>'],
#     'entity_name': ['love'],
#     'movie': ['<http://dbpedia.org/resource/Billy_Madison>'],
#     'movie_name': ['Billy Madison (1995)'],
#     'word_name': ['love', 'movie', 'madison', 'billy']},
#    {'timeOffset': 61,
#     'text': 'Yes that is great.',
#     'senderWorkerId': 976,
#     'messageId': 205306,
#     'entity': ['<http://dbpedia.org/resource/Yes_(band)>',
#      '<http://dbpedia.org/resource/Great_Britain>'],
#     'entity_name': ['Yes', 'great'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': []},
#    {'timeOffset': 85,
#     'text': "Would you like @191440 . It's old but pretty funny.",
#     'senderWorkerId': 976,
#     'messageId': 205307,
#     'entity': ['<http://dbpedia.org/resource/It>',
#      '<http://dbpedia.org/resource/Physical_attractiveness>',
#      '<http://dbpedia.org/resource/Humour>'],
#     'entity_name': ['It', 'pretty', 'funny'],
#     'movie': ['<http://dbpedia.org/resource/Shallow_Hal>'],
#     'movie_name': ['Shallow Hal (2001)'],
#     'word_name': ['2001', 'pretty', 'funny', 'hal', 'shallow']},
#    {'timeOffset': 112,
#     'text': "I have seen that movie and I really like it.  It's funny and heartwarming.",
#     'senderWorkerId': 959,
#     'messageId': 205308,
#     'entity': ['<http://dbpedia.org/resource/It>',
#      '<http://dbpedia.org/resource/Humour>'],
#     'entity_name': ['It', 'funny'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['heartwarming', 'movie', 'funny']},
#    {'timeOffset': 138,
#     'text': 'I like @136983 too.',
#     'senderWorkerId': 976,
#     'messageId': 205309,
#     'entity': [],
#     'entity_name': [],
#     'movie': ['<http://dbpedia.org/resource/Ghostbusters>'],
#     'movie_name': ['Ghostbusters (1984)'],
#     'word_name': ['ghostbusters']},
#    {'timeOffset': 145,
#     'text': "I'm stuck on Adam Sandler and Drew Berrymore have you seen @115908 ?",
#     'senderWorkerId': 959,
#     'messageId': 205310,
#     'entity': ['<http://dbpedia.org/resource/Wikipedia>',
#      '<http://dbpedia.org/resource/Striking_the_colors>',
#      '<http://dbpedia.org/resource/Adam_Sandler>'],
#     'entity_name': ["I'm", 'stuck', 'Adam Sandler'],
#     'movie': ['<http://dbpedia.org/resource/50_First_Dates>'],
#     'movie_name': ['50 First Dates (2004)'],
#     'word_name': ['50', 'stuck', 'drew', 'sandler', 'adam', 'dates']},
#    {'timeOffset': 153,
#     'text': 'Cool. Maybe I helped. Yes, I love that movie.',
#     'senderWorkerId': 976,
#     'messageId': 205311,
#     'entity': ['<http://dbpedia.org/resource/Cool>',
#      '<http://dbpedia.org/resource/Maybe_(The_Chantels_song)>',
#      '<http://dbpedia.org/resource/Introduced_species>',
#      '<http://dbpedia.org/resource/Yes_(band)>',
#      '<http://dbpedia.org/resource/Love>'],
#     'entity_name': ['Cool', 'Maybe', 'helped', 'Yes', 'love'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['love', 'helped', 'movie', 'cool']},
#    {'timeOffset': 164,
#     'text': 'Did o help you, or do you need more help?',
#     'senderWorkerId': 976,
#     'messageId': 205312,
#     'entity': [],
#     'entity_name': [],
#     'movie': [],
#     'movie_name': [],
#     'word_name': []},
#    {'timeOffset': 164,
#     'text': 'Oh I love @136983 .',
#     'senderWorkerId': 959,
#     'messageId': 205313,
#     'entity': ['<http://dbpedia.org/resource/Seung-hwan_Oh>',
#      '<http://dbpedia.org/resource/Love>'],
#     'entity_name': ['Oh', 'love'],
#     'movie': ['<http://dbpedia.org/resource/Ghostbusters>'],
#     'movie_name': ['Ghostbusters (1984)'],
#     'word_name': ['ghostbusters', 'love']},
#    {'timeOffset': 179,
#     'text': 'You definitely helped me thank you very much.',
#     'senderWorkerId': 959,
#     'messageId': 205314,
#     'entity': ['<http://dbpedia.org/resource/Israel>',
#      '<http://dbpedia.org/resource/Introduced_species>'],
#     'entity_name': ['You', 'helped'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['helped']},
#    {'timeOffset': 186,
#     'text': 'Great. Goodbye.',
#     'senderWorkerId': 976,
#     'messageId': 205315,
#     'entity': ['<http://dbpedia.org/resource/Great>',
#      '<http://dbpedia.org/resource/Goodbye_(Gordon_Jenkins_song)>'],
#     'entity_name': ['Great', 'Goodbye'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['goodbye']},
#    {'timeOffset': 193,
#     'text': 'goodbye.',
#     'senderWorkerId': 959,
#     'messageId': 205316,
#     'entity': ['<http://dbpedia.org/resource/Parting_phrase>'],
#     'entity_name': ['goodbye'],
#     'movie': [],
#     'movie_name': [],
#     'word_name': ['goodbye']}],
#   'conversationId': '20412',
#   'respondentWorkerId': 976,
#   'initiatorWorkerId': 959,
#   'initiatorQuestions': {'115908': {'suggested': 0, 'seen': 1, 'liked': 1},
#    '191440': {'suggested': 1, 'seen': 1, 'liked': 1},
#    '181301': {'suggested': 0, 'seen': 1, 'liked': 1},
#    '157394': {'suggested': 1, 'seen': 1, 'liked': 1},
#    '136983': {'suggested': 1, 'seen': 1, 'liked': 1}}}]
